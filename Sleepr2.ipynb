# %%
import time
from sleeper_wrapper import League, User, Stats, Players

players = Players()
start = time.time()
all_players = players.get_all_players()
end = time.time()
print("Time in seconds: ", end-start)
# Out:
# Time in seconds:  2.544189453125

# %%
import pandas as pd
import numpy as np

# %%
print (len(all_players))
# Out:
# 6754

# %%
class Team:
    def __init__(self, tid, data):
        self.tid = tid
        self.data = data 
        self.owner_id = data['owner_id']
        self.owner_name = ''
                
    def get_players(self):
        self.players = []
        for x in self.data['players']:
            player = Player(x)
            self.players.append(player)
            
    def pandas_players(self):
        columns = ['Name', 'Age', 'Team', 'Position', 'Fantasy', 'Depth_rank']
        self.get_players()
        d = []
        for player in self.players:
            d.append([player.name, player.age, player.team, player.position, player.fantasy_positions, player.depth_rank])
        data = pd.DataFrame(data=d, columns=columns)
        return data

# %%
class Player:
    def __init__(self, pid):
        self.data = all_players[pid]
        self.pid = pid
        self.name = self.data['full_name'] 
        self.position = self.data['position']
        self.fantasy_positions = self.data['fantasy_positions']
        self.age = self.data['age']
        self.team = self.data['team']
        self.depth_rank = self.data['depth_chart_order']
        self.status = self.data['status']
        
    def set_stats(self, stats):
        if len(stats) > 0:
            self.stats = stats
        else :
            self.stats = []

# %%
## Change league ID to change league 
## Pulls rosters and users for each league
## Also creates all the team objects for later use

## 10-team idp: 472461929810489344
## 12-team:     469555582068584448
league = League('472461929810489344')
rosters = league.get_rosters()
users = league.get_users()
teams = []
tid = 0
for x in rosters:
    team = Team(tid, rosters[tid])
    owner_name = ''
    for user in users:
        if user['user_id'] == team.owner_id:
            owner_name = user['display_name']
            team.owner_name = owner_name 
    print(owner_name, tid)
    tid += 1
    teams.append(team)
# Out:
# Jonny2Time 0
# Steeler1979 1
# MrLonghorn 2
# bmass 3
# Micahangelo 4
# JoSchmo 5
# Horny1 6
# FlashYourTDs 7
# BeerdedJustice 8
# MrJanuary 9

# %%
## Below cell calculate and prints the average age for each team in league

# %%
tid = 1
user2age = []
for team in teams:
    players = team.pandas_players()
    players = players.sort_values(by=['Age'])
    age = np.mean(players['Age'])
    tid += 1
    user2age.append((team.owner_name, age))
user2age.sort(key = lambda x: x[1], reverse=True)  
for entry in user2age:
    print("User: %s, Average Age: %.3f\n" % (entry[0], entry[1]))
# Out:
# User: WildcardSports, Average Age: 27.034
#
# User: JusMan, Average Age: 26.905
#
# User: Zfagan103, Average Age: 26.667
#
# User: PolkFiction, Average Age: 26.600
#
# User: kickinwing, Average Age: 26.037
#
# User: Oz75, Average Age: 25.583
#
# User: chett, Average Age: 25.462
#
# User: ravensarmy123, Average Age: 25.393
#
# User: MrLonghorn, Average Age: 25.250
#
# User: BXBenny, Average Age: 25.107
#
# User: jsemmens, Average Age: 24.929
#
# User: Philoh, Average Age: 24.379

# %%
username = 'MrLonghorn'
for team in teams:
    if team.owner_name == username:
        print(players)
# Out:
#                    Name  Age  Team Position   Fantasy  Depth_rank
# 13           Auden Tate   22   CIN       WR      [WR]           3
# 20       Marquise Brown   22   BAL       WR      [WR]           1
# 19       Dwayne Haskins   22   WAS       QB      [QB]           5
# 21        Damien Harris   22    NE       RB      [RB]           5
# 9         Derrius Guice   22   WAS       RB      [RB]           6
# 22        Foster Moreau   22   OAK       TE      [TE]           5
# 6   Christian McCaffrey   23   CAR       RB      [RB]           1
# 23     Jace Sternberger   23    GB       TE      [TE]           4
# 24      Jordan Scarlett   23   CAR       RB      [RB]           6
# 12           Ian Thomas   23   CAR       TE      [TE]           2
# 14      Reggie Bonnafon   23   CAR       RB  [WR, RB]           2
# 10       Christian Kirk   23   ARI       WR      [WR]           1
# 15         Allen Lazard   24    GB       WR      [WR]           1
# 8       Jamaal Williams   24    GB       RB      [RB]           2
# 17        Justin Watson   24    TB       WR      [WR]           1
# 11          Sony Michel   24    NE       RB      [RB]           1
# 3      Sterling Shepard   25   NYG       WR      [WR]           1
# 4     Jonathan Williams   25   IND       RB      [RB]           4
# 5           JD McKissic   26   DET       RB  [WR, RB]           4
# 7           Cooper Kupp   26   LAR       WR      [WR]           1
# 2     Teddy Bridgewater   27    NO       QB      [QB]           3
# 1            Derek Carr   28   OAK       QB      [QB]           1
# 26         Randall Cobb   29   DAL       WR      [WR]           1
# 0          Travis Kelce   30    KC       TE      [TE]           1
# 27           Cam Newton   30   CAR       QB      [QB]           3
# 16        Antonio Brown   31  None       WR      [WR]           1
# 25          Andy Dalton   32   CIN       QB      [QB]           1
# 18     Emmanuel Sanders   32    SF       WR      [WR]           1

# %%
## BELOW CELL
## Creates a list of unowned players using difference between all and owned

# %%
def is_pid(test):
    try:
        int(test)
        return True
    except ValueError:
        return False

owned_players = []
for team in teams:
    team.get_players()
    for player in team.players:
        owned_players.append(player.pid)
free_agent_set = set(all_players).difference(set(owned_players))
free_agents = []
for agent in list(free_agent_set):
    if is_pid(agent):
        player = Player(str(agent))
        free_agents.append(player)

# %%
#Finds free agents that are on IR

for agent in free_agents:
    if agent.status == 'Injured Reserve' and agent.team != 'None':
        print(agent.name)
# Out:
# Brandon Watts
# Rueben Randle
# Sean Davis
# Zach Allen
# Scott Miller
# Evan Panfil
# Josh Johnson
# James Hanna
# Ryan Disalvo
# Lynden Trail
# Lance Lenoir
# Corey Clement
# Alani Fua
# Drew Stanton
# Chris Prosinski
# Trevor Siemian
# Marqise Lee
# Nathan Peterman
# Kemoko Turay
# Equanimeous St. Brown
# Kahale Warring
# Trenton Cannon
# Emmett Cleary
# Gabe Ikard
# Pernell McPhee
# Kevin Norwood
# John Lovett
# Jakeem Grant
# Aaron Dobson
# Rashaun Allen
# Malik Smith
# Stephon Tuitt
# Ryan Connelly
# Jhajuan Seales
# Quincy Enunwa
# Rodney Anderson
# Corey Lemonier
# Jacoby Glenn
# Demetrius McCray
# Joe Bacci
# James O'Shaughnessy
# Gunner Olszewski
# Ka'Deem Carey
# Xavien Howard
# Karl Joseph
# Graham Gano
# Michael Cirino
# RJ Shelton
# Kurt Benkert
# Adam Vinatieri
# Jermaine Kearse
# Justin Evans
# Corbin Bryant
# Jordan Reed
# Brennen Beyer
# Jordan Scarlett
# Raven Greene
# Ricardo Louis
# Danny Woodhead
# Malik Jackson
# Sean Hickey
# Marcus Cromartie
# Paul Richardson
# Malcolm Butler
# Trevor Knight
# Byron Maxwell
# Drew Sample
# Emmanuel Ogbah
# Blake Cashman
# Jake Butt
# Isaiah Crowell
# Jon'vea Johnson
# Ron Thompson
# Lonnie Ballentine
# Chris Culliver
# D'Andre Walker
# Trent Taylor
# Reuben Foster
# Blaine Gabbert
# Zach Franklin
# JR Nelson
# Sefo Liufau
# Theo Riddick
# Derek Rivers
# Daurice Fountain
# Marquis Lucas
# Stephen Gostkowski
# Martin Wallace
# Joe Thomas
# Corey Coleman
# Micah Kiser
# JT Thomas
# Jalen Hurd
# Keyarris Garrett
# Kenneth Dixon
# Earl Wolff
# Travis Benjamin
# Marcus Rios
# Tony Jefferson
# CJ Fiedorowicz
# Erik Austell
# Matt Simms
# Keith Kirkwood
# Ed Dickson
# Zach Strief
# Dez Stewart
# Donald Hawkins
# BJ Johnson
# Paul Posluszny
# Adam Shaheen
# D.J. Montgomery
# Alex Anzalone
# Russell Shepard
# Tim Lelito
# David Fluellen
# Jonathan Ledbetter
# Erik Walden
# Jon Dorenbos
# Connor Shaw
# Quincy Williams
# Matt Forte
# Geoff Swaim
# Jimmy Staten
# EJ Bibbs
# Austin Fort
# Paul McRoberts
# Chris Matthews
# Evan Schwan

# %%
stats = Stats()
all_stats = stats.get_all_stats('regular', '2019')
print(all_stats)
for pid in all_stats.keys():
    if is_pid(pid):
        player = Player(pid)
        player.set_stats(all_stats[pid])
        if len(player.stats) > 0:
            print(player.name, player.stats)
# Out:
# {'6250': {}, '6177': {'wind_speed': 147.0, 'tm_st_snp': 325.0, 'tm_off_snp': 1012.0, 'tm_def_snp': 1043.0, 'temperature': 794.0, 'st_snp': 3.0, 'pts_std': 22.5, 'pts_ppr': 22.5, 'pts_half_ppr': 22.5, 'idp_tkl_solo': 13.0, 'idp_tkl_ast': 9.0, 'idp_tkl': 22.0, 'idp_sack': 1.0, 'idp_qb_hit': 2.0, 'idp_pass_def': 1.0, 'humidity': 867.0, 'gs': 4.0, 'gp': 11.0, 'gms_active': 11.0, 'def_snp': 292.0}, '5870': {'pass_2pt': 2.0, 'pass_int': 11.0, 'pass_lng': 520.0, 'off_snp': 752.0, 'gs': 11.0, 'cmp_pct': 755.5, 'pass_fd': 104.0, 'gp': 12.0, 'pass_sack': 34.0, 'tm_off_snp': 1007.0, 'pass_td_40p': 3.0, 'wind_speed': 136.0, 'bonus_pass_cmp_25': 4.0, 'gms_active': 13.0, 'pass_cmp': 256.0, 'pts_half_ppr': 200.3, 'pass_rtg': 1041.03, 'idp_tkl': 3.0, 'pass_sack_yds': 269.0, 'tm_def_snp': 1062.0, 'rush_ypa': 6.02, 'temperature': 848.0, 'rush_fd': 20.0, 'bonus_pass_yd_300': 4.0, 'pass_att': 412.0, 'pass_inc': 156.0, 'pass_cmp_40p': 7.0, 'pass_ypa': 6.62, 'rush_att': 42.0, 'idp_tkl_solo': 3.0, 'td': 2.0, 'rush_lng': 139.0, 'tm_st_snp': 370.0, 'rush_yd': 253.0, 'pass_yd': 2726.0, 'pass_td': 23.0, 'rush_td': 2.0, 'pts_ppr': 200.34, 'fum_lost': 10.0, 'humidity': 904.0, 'fum': 16.0, 'pts_std': 200.34, 'pass_ypc': 10.65}, '4297': {}, '1347': {}, '1023': {'wind_speed': 112.0, 'tm_st_snp': 334.0, 'tm_off_snp': 994.0, 'tm_def_snp': 934.0, 'temperature': 938.0, 'st_snp': 2.0, 'off_snp': 309.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 910.0, 'gs': 5.0, 'gp': 5.0, 'gms_active': 5.0}, '5300': {'wind_speed': 115.0, 'tm_st_snp': 360.0, 'tm_off_snp': 1086.0, 'tm_def_snp': 980.0, 'temperature': 950.0, 'st_snp': 188.0, 'pts_std': 20.0, 'pts_ppr': 20.0, 'pts_half_ppr': 20.0, 'idp_tkl_solo': 14.0, 'idp_tkl_loss': 3.0, 'idp_tkl_ast': 2.0, 'idp_tkl': 16.0, 'idp_qb_hit': 2.0, 'humidity': 811.0, 'gs': 3.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 101.0}, '608': {'wind_speed': 79.0, 'tm_st_snp': 373.0, 'tm_off_snp': 997.0, 'tm_def_snp': 1078.0, 'temperature': 993.0, 'st_snp': 148.0, 'sack_yd': 17.5, 'pts_std': 44.75, 'pts_ppr': 44.75, 'pts_half_ppr': 44.8, 'idp_tkl_solo': 18.0, 'idp_tkl_loss': 5.5, 'idp_tkl_ast': 17.0, 'idp_tkl': 35.0, 'idp_sack': 2.5, 'idp_qb_hit': 6.0, 'humidity': 982.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 767.0}, '3925': {}, '3396': {}, '6343': {}, '3199': {'rec_yd': 1688.0, 'off_snp': 913.0, 'gs': 14.0, 'rec_30_39': 2.0, 'bonus_rush_rec_yd_100': 10.0, 'gp': 15.0, 'tm_off_snp': 1014.0, 'wind_speed': 93.0, 'rec_ypt': 9.59, 'rec_pct': 1241.0, 'gms_active': 15.0, 'rec_ypr': 11.64, 'pts_half_ppr': 294.4, 'rec_20_29': 12.0, 'st_snp': 7.0, 'rec_0_4': 13.0, 'tm_def_snp': 1012.0, 'rush_ypa': -9.0, 'temperature': 980.0, 'rec': 145.0, 'rec_5_9': 61.0, 'rush_att': 1.0, 'td': 9.0, 'rec_td': 9.0, 'rush_lng': -9.0, 'rec_lng': 407.0, 'rec_10_19': 54.0, 'rec_tgt': 176.0, 'tm_st_snp': 346.0, 'rush_yd': -9.0, 'rec_40p': 3.0, 'bonus_rec_wr': 145.0, 'pts_ppr': 366.9, 'bonus_rec_yd_100': 10.0, 'humidity': 988.0, 'fum': 1.0, 'pts_std': 221.9, 'rec_fd': 81.0}, '6487': {}, '2355': {'wind_speed': 160.0, 'tm_st_snp': 359.0, 'tm_off_snp': 1110.0, 'tm_def_snp': 963.0, 'temperature': 874.0, 'st_snp': 7.0, 'pts_std': 53.5, 'pts_ppr': 53.5, 'pts_half_ppr': 53.5, 'idp_tkl_solo': 34.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 37.0, 'idp_pass_def': 11.0, 'idp_int_ret_yd': 29.0, 'idp_int': 2.0, 'humidity': 898.0, 'gs': 11.0, 'gp': 11.0, 'gms_active': 12.0, 'def_snp': 522.0}, '1952': {}, '3210': {}, '4148': {'wind_speed': 129.0, 'tm_st_snp': 357.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1036.0, 'temperature': 880.0, 'st_snp': 10.0, 'sack_yd': 17.0, 'pts_std': 46.7, 'pts_ppr': 46.7, 'pts_half_ppr': 46.7, 'idp_tkl_solo': 14.0, 'idp_tkl_loss': 4.5, 'idp_tkl_ast': 5.0, 'idp_tkl': 19.0, 'idp_sack': 3.0, 'idp_qb_hit': 18.0, 'humidity': 1028.0, 'gs': 2.0, 'gp': 11.0, 'gms_active': 12.0, 'def_snp': 429.0}, '5781': {'wind_speed': 84.0, 'tm_st_snp': 284.0, 'tm_off_snp': 996.0, 'tm_def_snp': 967.0, 'temperature': 772.0, 'td': 1.0, 'st_snp': 159.0, 'rec_ypt':  ...
# Khalen Saunders {'wind_speed': 147.0, 'tm_st_snp': 325.0, 'tm_off_snp': 1012.0, 'tm_def_snp': 1043.0, 'temperature': 794.0, 'st_snp': 3.0, 'pts_std': 22.5, 'pts_ppr': 22.5, 'pts_half_ppr': 22.5, 'idp_tkl_solo': 13.0, 'idp_tkl_ast': 9.0, 'idp_tkl': 22.0, 'idp_sack': 1.0, 'idp_qb_hit': 2.0, 'idp_pass_def': 1.0, 'humidity': 867.0, 'gs': 4.0, 'gp': 11.0, 'gms_active': 11.0, 'def_snp': 292.0}
# Daniel Jones {'pass_2pt': 2.0, 'pass_int': 11.0, 'pass_lng': 520.0, 'off_snp': 752.0, 'gs': 11.0, 'cmp_pct': 755.5, 'pass_fd': 104.0, 'gp': 12.0, 'pass_sack': 34.0, 'tm_off_snp': 1007.0, 'pass_td_40p': 3.0, 'wind_speed': 136.0, 'bonus_pass_cmp_25': 4.0, 'gms_active': 13.0, 'pass_cmp': 256.0, 'pts_half_ppr': 200.3, 'pass_rtg': 1041.03, 'idp_tkl': 3.0, 'pass_sack_yds': 269.0, 'tm_def_snp': 1062.0, 'rush_ypa': 6.02, 'temperature': 848.0, 'rush_fd': 20.0, 'bonus_pass_yd_300': 4.0, 'pass_att': 412.0, 'pass_inc': 156.0, 'pass_cmp_40p': 7.0, 'pass_ypa': 6.62, 'rush_att': 42.0, 'idp_tkl_solo': 3.0, 'td': 2.0, 'rush_lng': 139.0, 'tm_st_snp': 370.0, 'rush_yd': 253.0, 'pass_yd': 2726.0, 'pass_td': 23.0, 'rush_td': 2.0, 'pts_ppr': 200.34, 'fum_lost': 10.0, 'humidity': 904.0, 'fum': 16.0, 'pts_std': 200.34, 'pass_ypc': 10.65}
# Mike Pouncey {'wind_speed': 112.0, 'tm_st_snp': 334.0, 'tm_off_snp': 994.0, 'tm_def_snp': 934.0, 'temperature': 938.0, 'st_snp': 2.0, 'off_snp': 309.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 910.0, 'gs': 5.0, 'gp': 5.0, 'gms_active': 5.0}
# Kenny Young {'wind_speed': 115.0, 'tm_st_snp': 360.0, 'tm_off_snp': 1086.0, 'tm_def_snp': 980.0, 'temperature': 950.0, 'st_snp': 188.0, 'pts_std': 20.0, 'pts_ppr': 20.0, 'pts_half_ppr': 20.0, 'idp_tkl_solo': 14.0, 'idp_tkl_loss': 3.0, 'idp_tkl_ast': 2.0, 'idp_tkl': 16.0, 'idp_qb_hit': 2.0, 'humidity': 811.0, 'gs': 3.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 101.0}
# Corey Peters {'wind_speed': 79.0, 'tm_st_snp': 373.0, 'tm_off_snp': 997.0, 'tm_def_snp': 1078.0, 'temperature': 993.0, 'st_snp': 148.0, 'sack_yd': 17.5, 'pts_std': 44.75, 'pts_ppr': 44.75, 'pts_half_ppr': 44.8, 'idp_tkl_solo': 18.0, 'idp_tkl_loss': 5.5, 'idp_tkl_ast': 17.0, 'idp_tkl': 35.0, 'idp_sack': 2.5, 'idp_qb_hit': 6.0, 'humidity': 982.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 767.0}
# Michael Thomas {'rec_yd': 1688.0, 'off_snp': 913.0, 'gs': 14.0, 'rec_30_39': 2.0, 'bonus_rush_rec_yd_100': 10.0, 'gp': 15.0, 'tm_off_snp': 1014.0, 'wind_speed': 93.0, 'rec_ypt': 9.59, 'rec_pct': 1241.0, 'gms_active': 15.0, 'rec_ypr': 11.64, 'pts_half_ppr': 294.4, 'rec_20_29': 12.0, 'st_snp': 7.0, 'rec_0_4': 13.0, 'tm_def_snp': 1012.0, 'rush_ypa': -9.0, 'temperature': 980.0, 'rec': 145.0, 'rec_5_9': 61.0, 'rush_att': 1.0, 'td': 9.0, 'rec_td': 9.0, 'rush_lng': -9.0, 'rec_lng': 407.0, 'rec_10_19': 54.0, 'rec_tgt': 176.0, 'tm_st_snp': 346.0, 'rush_yd': -9.0, 'rec_40p': 3.0, 'bonus_rec_wr': 145.0, 'pts_ppr': 366.9, 'bonus_rec_yd_100': 10.0, 'humidity': 988.0, 'fum': 1.0, 'pts_std': 221.9, 'rec_fd': 81.0}
# Ronald Darby {'wind_speed': 160.0, 'tm_st_snp': 359.0, 'tm_off_snp': 1110.0, 'tm_def_snp': 963.0, 'temperature': 874.0, 'st_snp': 7.0, 'pts_std': 53.5, 'pts_ppr': 53.5, 'pts_half_ppr': 53.5, 'idp_tkl_solo': 34.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 37.0, 'idp_pass_def': 11.0, 'idp_int_ret_yd': 29.0, 'idp_int': 2.0, 'humidity': 898.0, 'gs': 11.0, 'gp': 11.0, 'gms_active': 12.0, 'def_snp': 522.0}
# Carl Lawson {'wind_speed': 129.0, 'tm_st_snp': 357.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1036.0, 'temperature': 880.0, 'st_snp': 10.0, 'sack_yd': 17.0, 'pts_std': 46.7, 'pts_ppr': 46.7, 'pts_half_ppr': 46.7, 'idp_tkl_solo': 14.0, 'idp_tkl_loss': 4.5, 'idp_tkl_ast': 5.0, 'idp_tkl': 19.0, 'idp_sack': 3.0, 'idp_qb_hit': 18.0, 'humidity': 1028.0, 'gs': 2.0, 'gp': 11.0, 'gms_active': 12.0, 'def_snp': 429.0}
# Malik Turner {'wind_speed': 84.0, 'tm_st_snp': 284.0, 'tm_off_snp': 996.0, 'tm_def_snp': 967.0, 'temperature': 772.0, 'td': 1.0, 'st_snp': 159.0, 'rec_ypt': 11.14, 'rec_ypr': 16.33, 'rec_yd': 245.0, 'rec_tgt': 22.0, 'rec_td': 1.0, 'rec_pct': 683.3, 'rec_lng': 195.0, 'rec_fd': 9.0, 'rec_5_9': 5.0, 'rec_30_39': 2.0, 'rec_20_29': 4.0, 'rec_10_19': 4.0, 'rec': 15.0, 'pts_std': 30.5, 'pts_ppr': 45.5, 'pts_half_ppr': 38.0, 'off_snp': 231.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 744.0, 'gs': 3.0, 'gp': 14.0, 'gms_active': 14.0, 'bonus_rec_wr': 15.0}
# Justin Bethel {'wind_speed': 124.0, 'tm_st_snp': 353.0, 'tm_off_snp': 1101.0, 'tm_def_snp': 970.0, 'temperature': 810.0, 'st_snp': 344.0, 'pts_std': 18.5, 'pts_ppr': 18.5, 'pts_half_ppr': 18.5, 'idp_tkl_solo': 8.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 11.0, 'idp_fum_ret_yd': -1.0, 'idp_fum_rec': 3.0, 'humidity': 918.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 21.0}
# Calvin Ridley {'rec_yd': 866.0, 'off_snp': 732.0, 'gs': 10.0, 'rec_30_39': 4.0, 'bonus_rush_rec_yd_100': 3.0, 'gp': 13.0, 'tm_off_snp': 959.0, 'wind_speed': 93.0, 'rec_ypt': 9.31, 'rec_pct': 925.7, 'gms_active': 13.0, 'rec_ypr': 13.75, 'pts_half_ppr': 165.5, 'rec_20_29': 8.0, 'idp_tkl': 1.0, 'rec_0_4': 7.0, 'tm_def_snp': 871.0, 'rush_ypa': 17.0, 'temperature': 884.0, 'rush_fd': 2.0, 'rec_2pt': 1.0, 'rec': 63.0, 'rec_5_9': 15.0, 'rush_att': 2.0, 'idp_tkl_solo': 1.0, 'td': 7.0, 'rec_td': 7.0, 'rush_lng': 34.0, 'rec_lng': 285.0, 'rec_10_19': 29.0, 'rec_tgt': 93.0, 'tm_st_snp': 303.0, 'rush_yd': 34.0, 'bonus_rec_wr': 63.0, 'pts_ppr': 197.0, 'bonus_rec_yd_100': 2.0, 'humidity': 773.0, 'pts_std': 134.0, 'rec_fd': 40.0}
# PJ Williams {'wind_speed': 80.0, 'tm_st_snp': 297.0, 'tm_off_snp': 860.0, 'tm_def_snp': 898.0, 'temperature': 856.0, 'st_snp': 52.0, 'sack_yd': 1.0, 'pts_std': 47.6, 'pts_ppr': 47.6, 'pts_half_ppr': 47.6, 'idp_tkl_solo': 31.0, 'idp_tkl_loss': 2.0, 'idp_tkl_ast': 9.0, 'idp_tkl': 40.0, 'idp_sack': 1.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 4.0, 'idp_int': 1.0, 'humidity': 889.0, 'gs': 7.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 744.0}
# Albert Wilson {'rec_yd': 292.0, 'off_snp': 374.0, 'gs': 3.0, 'rec_30_39': 1.0, 'gp': 12.0, 'pass_sack': 1.0, 'tm_off_snp': 1017.0, 'wind_speed': 178.0, 'rec_ypt': 5.41, 'rec_pct': 764.8, 'gms_active': 12.0, 'rec_ypr': 7.68, 'pts_half_ppr': 58.7, 'rec_20_29': 2.0, 'st_snp': 4.0, 'rec_0_4': 10.0, 'pass_sack_yds': 10.0, 'tm_def_snp': 1060.0, 'rush_ypa': 9.0, 'temperature': 1016.0, 'rush_fd': 1.0, 'rec': 38.0, 'rec_5_9': 12.0, 'rush_att': 5.0, 'td': 1.0, 'rec_td': 1.0, 'rush_lng': 42.0, 'rec_lng': 153.0, 'rec_10_19': 10.0, 'rec_tgt': 54.0, 'tm_st_snp': 370.0, 'rush_yd': 45.0, 'bonus_rec_wr': 38.0, 'pts_ppr': 77.7, 'humidity': 894.0, 'pts_std': 39.7, 'rec_fd': 17.0}
# Josiah Tauaefa {'wind_speed': 102.0, 'tm_st_snp': 276.0, 'tm_off_snp': 725.0, 'tm_def_snp': 790.0, 'temperature': 537.0, 'st_snp': 192.0, 'pts_std': 10.5, 'pts_ppr': 10.5, 'pts_half_ppr': 10.5, 'idp_tkl_solo': 5.0, 'idp_tkl_loss': 2.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 6.0, 'idp_ff': 1.0, 'humidity': 655.0, 'gp': 11.0, 'gms_active': 11.0, 'def_snp': 23.0}
# Jon Condo {'wind_speed': 4.0, 'tm_st_snp': 22.0, 'tm_off_snp': 79.0, 'tm_def_snp': 53.0, 'temperature': 70.0, 'st_snp': 7.0, 'humidity': 64.0, 'gp': 1.0, 'gms_active': 1.0}
# Laken Tomlinson {'wind_speed': 67.0, 'tm_st_snp': 329.0, 'tm_off_snp': 1036.0, 'tm_def_snp': 946.0, 'temperature': 929.0, 'st_snp': 88.0, 'off_snp': 1035.0, 'idp_tkl_solo': 2.0, 'idp_tkl': 2.0, 'humidity': 886.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0}
# Trent Taylor {'wind_speed': 12.0, 'tm_st_snp': 42.0, 'tm_off_snp': 140.0, 'tm_def_snp': 140.0, 'temperature': 169.0, 'humidity': 158.0, 'gp': 2.0}
# MyCole Pruitt {'wind_speed': 93.0, 'tm_st_snp': 355.0, 'tm_off_snp': 955.0, 'tm_def_snp': 1060.0, 'temperature': 880.0, 'st_snp': 222.0, 'rec_ypt': 12.83, 'rec_ypr': 19.25, 'rec_yd': 77.0, 'rec_tgt': 6.0, 'rec_pct': 300.0, 'rec_lng': 72.0, 'rec_fd': 2.0, 'rec_5_9': 1.0, 'rec_40p': 1.0, 'rec_20_29': 1.0, 'rec_10_19': 1.0, 'rec': 4.0, 'pts_std': 7.7, 'pts_ppr': 11.7, 'pts_half_ppr': 9.7, 'off_snp': 416.0, 'idp_tkl_solo': 1.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 2.0, 'humidity': 865.0, 'gs': 10.0, 'gp': 15.0, 'gms_active': 15.0, 'bonus_rec_te': 4.0}
# Keisean Nixon {'wind_speed': 110.0, 'tm_st_snp': 349.0, 'tm_off_snp': 964.0, 'tm_def_snp': 999.0, 'temperature': 803.0, 'st_snp': 240.0, 'pts_std': 13.0, 'pts_ppr': 13.0, 'pts_half_ppr': 13.0, 'kr_ypa': 25.5, 'kr_yd': 51.0, 'kr_lng': 26.0, 'kr': 2.0, 'idp_tkl_solo': 12.0, 'idp_tkl': 12.0, 'idp_pass_def': 1.0, 'humidity': 824.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 38.0}
# Brian Parker {'wind_speed': 7.0, 'tm_st_snp': 27.0, 'tm_off_snp': 78.0, 'tm_def_snp': 65.0, 'temperature': 54.0, 'humidity': 38.0, 'gp': 1.0}
# Corey Levin {'wind_speed': 57.0, 'tm_st_snp': 106.0, 'tm_off_snp': 366.0, 'tm_def_snp': 317.0, 'temperature': 212.0, 'humidity': 169.0, 'gp': 5.0}
# Maurice Canady {'wind_speed': 106.0, 'tm_st_snp': 334.0, 'tm_off_snp': 986.0, 'tm_def_snp': 925.0, 'temperature': 713.0, 'st_snp': 119.0, 'pts_std': 52.0, 'pts_ppr': 52.0, 'pts_half_ppr': 52.0, 'idp_tkl_solo': 36.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 8.0, 'idp_tkl': 44.0, 'idp_pass_def': 5.0, 'idp_int_ret_yd': 3.0, 'idp_int': 1.0, 'idp_ff': 1.0, 'humidity': 753.0, 'gs': 2.0, 'gp': 12.0, 'gms_active': 12.0, 'def_snp': 339.0}
# John Kelly {'wind_speed': 25.0, 'tm_st_snp': 123.0, 'tm_off_snp': 323.0, 'tm_def_snp': 365.0, 'temperature': 299.0, 'st_snp': 38.0, 'rush_ypa': 3.0, 'rush_yd': 9.0, 'rush_lng': 6.0, 'rush_att': 3.0, 'pts_std': 0.9, 'pts_ppr': 0.9, 'pts_half_ppr': 0.9, 'off_snp': 4.0, 'humidity': 241.0, 'gp': 3.0, 'gms_active': 4.0}
# Colt McCoy {'wind_speed': 124.0, 'tm_st_snp': 352.0, 'tm_off_snp': 899.0, 'tm_def_snp': 1070.0, 'temperature': 834.0, 'rush_ypa': 7.0, 'rush_yd': 14.0, 'rush_lng': 9.0, 'rush_fd': 1.0, 'rush_att': 2.0, 'pts_std': 4.28, 'pts_ppr': 4.28, 'pts_half_ppr': 4.3, 'pass_ypc': 6.78, 'pass_ypa': 4.52, 'pass_yd': 122.0, 'pass_sack_yds': 44.0, 'pass_sack': 6.0, 'pass_rtg': 61.03, 'pass_lng': 22.0, 'pass_int': 1.0, 'pass_inc': 9.0, 'pass_fd': 5.0, 'pass_cmp': 18.0, 'pass_att': 27.0, 'off_snp': 59.0, 'humidity': 676.0, 'gs': 1.0, 'gp': 1.0, 'gms_active': 2.0, 'fum': 2.0, 'cmp_pct': 66.7}
# Trae Waynes {'wind_speed': 118.0, 'tm_st_snp': 306.0, 'tm_off_snp': 987.0, 'tm_def_snp': 1026.0, 'temperature': 757.0, 'st_snp': 28.0, 'pts_std': 81.0, 'pts_ppr': 81.0, 'pts_half_ppr': 81.0, 'idp_tkl_solo': 56.0, 'idp_tkl_loss': 4.0, 'idp_tkl_ast': 2.0, 'idp_tkl': 58.0, 'idp_pass_def': 8.0, 'idp_int': 1.0, 'idp_fum_ret_yd': 20.0, 'idp_fum_rec': 1.0, 'idp_ff': 2.0, 'humidity': 850.0, 'gs': 14.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 782.0}
# Isaac Seumalo {'wind_speed': 160.0, 'tm_st_snp': 359.0, 'tm_off_snp': 1110.0, 'tm_def_snp': 963.0, 'temperature': 874.0, 'st_snp': 58.0, 'off_snp': 1108.0, 'idp_tkl_solo': 1.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 2.0, 'humidity': 898.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0}
# Matthias Farley {'wind_speed': 115.0, 'tm_st_snp': 368.0, 'tm_off_snp': 968.0, 'tm_def_snp': 1059.0, 'temperature': 821.0, 'st_snp': 195.0, 'pts_std': 4.5, 'pts_ppr': 4.5, 'pts_half_ppr': 4.5, 'idp_tkl_solo': 4.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 5.0, 'humidity': 795.0, 'gp': 12.0, 'gms_active': 13.0, 'def_snp': 4.0}
# Ryan Anderson {'wind_speed': 124.0, 'tm_st_snp': 352.0, 'tm_off_snp': 899.0, 'tm_def_snp': 1070.0, 'temperature': 834.0, 'st_snp': 205.0, 'sack_yd': 22.0, 'pts_std': 79.2, 'pts_ppr': 79.2, 'pts_half_ppr': 79.2, 'off_snp': 5.0, 'idp_tkl_solo': 26.0, 'idp_tkl_loss': 5.0, 'idp_tkl_ast': 14.0, 'idp_tkl': 40.0, 'idp_sack': 4.0, 'idp_qb_hit': 9.0, 'idp_pass_def': 1.0, 'idp_fum_rec': 2.0, 'idp_ff': 5.0, 'humidity': 676.0, 'gs': 3.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 501.0}
# Alec Ogletree {'wind_speed': 136.0, 'tm_st_snp': 370.0, 'tm_off_snp': 1007.0, 'tm_def_snp': 1062.0, 'temperature': 848.0, 'st_snp': 2.0, 'sack_yd': 4.0, 'pts_std': 80.9, 'pts_ppr': 80.9, 'pts_half_ppr': 80.9, 'idp_tkl_solo': 46.0, 'idp_tkl_loss': 6.0, 'idp_tkl_ast': 29.0, 'idp_tkl': 75.0, 'idp_sack': 1.0, 'idp_qb_hit': 3.0, 'idp_pass_def': 6.0, 'idp_int': 1.0, 'humidity': 904.0, 'gs': 12.0, 'gp': 12.0, 'gms_active': 13.0, 'def_snp': 820.0}
# Tre'Davious White {'wind_speed': 127.0, 'tm_st_snp': 278.0, 'tm_off_snp': 1033.0, 'tm_def_snp': 986.0, 'temperature': 816.0, 'st_snp': 79.0, 'sack_yd': 9.0, 'pts_std': 98.4, 'pts_ppr': 98.4, 'pts_half_ppr': 98.4, 'idp_tkl_solo': 48.0, 'idp_tkl_loss': 4.5, 'idp_tkl_ast': 10.0, 'idp_tkl': 58.0, 'idp_sack': 1.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 16.0, 'idp_int_ret_yd': 57.0, 'idp_int': 6.0, 'idp_ff': 1.0, 'humidity': 874.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 966.0}
# Chris Lacy {'wind_speed': 25.0, 'tm_st_snp': 98.0, 'tm_off_snp': 261.0, 'tm_def_snp': 282.0, 'temperature': 134.0, 'st_snp': 39.0, 'rec_ypt': 16.0, 'rec_ypr': 48.0, 'rec_yd': 48.0, 'rec_tgt': 3.0, 'rec_pct': 50.0, 'rec_lng': 48.0, 'rec_fd': 1.0, 'rec_40p': 1.0, 'rec': 1.0, 'pts_std': 4.8, 'pts_ppr': 5.8, 'pts_half_ppr': 5.3, 'off_snp': 72.0, 'kr_ypa': 23.0, 'kr_yd': 23.0, 'kr_lng': 23.0, 'kr': 1.0, 'humidity': 95.0, 'gs': 1.0, 'gp': 4.0, 'gms_active': 4.0, 'bonus_rec_wr': 1.0}
# Aviante Collins {'wind_speed': 39.0, 'tm_st_snp': 115.0, 'tm_off_snp': 310.0, 'tm_def_snp': 360.0, 'temperature': 189.0, 'st_snp': 3.0, 'humidity': 119.0, 'gp': 1.0, 'gms_active': 1.0}
# Bobby McCain {'wind_speed': 178.0, 'tm_st_snp': 370.0, 'tm_off_snp': 1017.0, 'tm_def_snp': 1060.0, 'temperature': 1016.0, 'st_snp': 27.0, 'pts_std': 31.0, 'pts_ppr': 31.0, 'pts_half_ppr': 31.0, 'idp_tkl_solo': 19.0, 'idp_tkl_ast': 6.0, 'idp_tkl': 25.0, 'idp_pass_def': 3.0, 'idp_int_ret_yd': 53.0, 'idp_int': 2.0, 'humidity': 894.0, 'gs': 8.0, 'gp': 9.0, 'gms_active': 9.0, 'fum': 1.0, 'def_snp': 548.0}
# Chad Slade {'wind_speed': 102.0, 'tm_st_snp': 276.0, 'tm_off_snp': 725.0, 'tm_def_snp': 790.0, 'temperature': 537.0, 'humidity': 655.0, 'gp': 11.0, 'gms_active': 1.0}
# Gerald Everett {'rec_yd': 408.0, 'off_snp': 455.0, 'gs': 2.0, 'rec_30_39': 3.0, 'bonus_rush_rec_yd_100': 1.0, 'gp': 12.0, 'tm_off_snp': 1052.0, 'wind_speed': 102.0, 'rec_ypt': 6.8, 'bonus_rec_te': 37.0, 'rec_pct': 814.5, 'gms_active': 12.0, 'rec_ypr': 11.03, 'pts_half_ppr': 71.3, 'rec_20_29': 3.0, 'st_snp': 1.0, 'rec_0_4': 7.0, 'tm_def_snp': 1042.0, 'temperature': 924.0, 'rec': 37.0, 'rec_5_9': 13.0, 'rush_att': 1.0, 'td': 2.0, 'rec_td': 2.0, 'rec_lng': 184.0, 'rec_10_19': 10.0, 'rec_tgt': 60.0, 'tm_st_snp': 371.0, 'pts_ppr': 89.8, 'bonus_rec_yd_100': 1.0, 'humidity': 720.0, 'pts_std': 52.8, 'rec_fd': 20.0}
# Cooper Rush {'wind_speed': 153.0, 'tm_st_snp': 297.0, 'tm_off_snp': 1055.0, 'tm_def_snp': 1039.0, 'temperature': 897.0, 'off_snp': 5.0, 'humidity': 948.0, 'gp': 2.0, 'gms_active': 15.0}
# Devine Ozigbo {'wind_speed': 122.0, 'tm_st_snp': 363.0, 'tm_off_snp': 1039.0, 'tm_def_snp': 1013.0, 'temperature': 976.0, 'st_snp': 107.0, 'off_snp': 6.0, 'idp_tkl_solo': 2.0, 'idp_tkl': 2.0, 'humidity': 1029.0, 'gp': 9.0, 'gms_active': 9.0}
# Brandon Dillon {'wind_speed': 6.0, 'tm_st_snp': 18.0, 'tm_off_snp': 53.0, 'tm_def_snp': 78.0, 'temperature': 58.0, 'off_snp': 7.0, 'humidity': 100.0, 'gp': 1.0, 'gms_active': 1.0}
# Marcedes Lewis {'wind_speed': 119.0, 'tm_st_snp': 313.0, 'tm_off_snp': 1020.0, 'tm_def_snp': 987.0, 'temperature': 724.0, 'td': 1.0, 'st_snp': 58.0, 'rec_ypt': 8.0, 'rec_ypr': 10.29, 'rec_yd': 144.0, 'rec_tgt': 18.0, 'rec_td': 1.0, 'rec_pct': 866.7, 'rec_lng': 103.0, 'rec_fd': 6.0, 'rec_5_9': 5.0, 'rec_20_29': 2.0, 'rec_10_19': 4.0, 'rec_0_4': 3.0, 'rec': 14.0, 'pts_std': 20.4, 'pts_ppr': 34.4, 'pts_half_ppr': 27.4, 'off_snp': 468.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 698.0, 'gs': 11.0, 'gp': 15.0, 'gms_active': 15.0, 'bonus_rec_te': 14.0}
# Jonathan Hilliman {'wind_speed': 31.0, 'tm_st_snp': 61.0, 'tm_off_snp': 197.0, 'tm_def_snp': 204.0, 'temperature': 189.0, 'st_snp': 13.0, 'rush_ypa': 3.03, 'rush_yd': 91.0, 'rush_lng': 23.0, 'rush_fd': 3.0, 'rush_att': 30.0, 'rec_ypt': 0.25, 'rec_ypr': 0.33, 'rec_yd': 1.0, 'rec_tgt': 4.0, 'rec_pct': 150.0, 'rec_lng': 9.0, 'rec_0_4': 1.0, 'rec': 3.0, 'pts_std': 5.2, 'pts_ppr': 8.2, 'pts_half_ppr': 6.7, 'off_snp': 102.0, 'humidity': 193.0, 'gs': 1.0, 'gp': 3.0, 'gms_active': 3.0, 'fum_lost': 2.0, 'fum': 2.0, 'bonus_rec_rb': 3.0}
# LaRoy Reynolds {'wind_speed': 120.0, 'tm_st_snp': 331.0, 'tm_off_snp': 977.0, 'tm_def_snp': 983.0, 'temperature': 821.0, 'st_snp': 240.0, 'pts_std': 7.5, 'pts_ppr': 7.5, 'pts_half_ppr': 7.5, 'idp_tkl_solo': 5.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 6.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 1.0, 'humidity': 928.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 44.0}
# Joshua Kalu {'wind_speed': 45.0, 'tm_st_snp': 148.0, 'tm_off_snp': 356.0, 'tm_def_snp': 436.0, 'temperature': 278.0, 'st_snp': 122.0, 'pts_std': 4.0, 'pts_ppr': 4.0, 'pts_half_ppr': 4.0, 'idp_tkl_solo': 4.0, 'idp_tkl': 4.0, 'idp_blk_kick': 1.0, 'humidity': 347.0, 'gp': 6.0, 'gms_active': 6.0, 'def_snp': 32.0}
# Corey Davis {'rec_yd': 557.0, 'off_snp': 691.0, 'gs': 10.0, 'rec_30_39': 1.0, 'gp': 14.0, 'tm_off_snp': 955.0, 'wind_speed': 93.0, 'rec_ypt': 8.7, 'rec_pct': 819.0, 'gms_active': 14.0, 'rec_ypr': 14.28, 'pts_half_ppr': 87.2, 'rec_20_29': 9.0, 'st_snp': 1.0, 'idp_tkl': 1.0, 'rec_0_4': 2.0, 'tm_def_snp': 1060.0, 'temperature': 880.0, 'rec': 39.0, 'rec_5_9': 10.0, 'idp_tkl_solo': 1.0, 'td': 2.0, 'rec_td': 2.0, 'rec_lng': 287.0, 'rec_10_19': 17.0, 'rec_tgt': 64.0, 'tm_st_snp': 355.0, 'bonus_rec_wr': 39.0, 'pts_ppr': 106.7, 'humidity': 865.0, 'fum': 1.0, 'pts_std': 67.7, 'rec_fd': 27.0}
# Antone Exum {'wind_speed': 26.0, 'tm_st_snp': 144.0, 'tm_off_snp': 407.0, 'tm_def_snp': 402.0, 'temperature': 402.0, 'st_snp': 98.0, 'pts_std': 1.5, 'pts_ppr': 1.5, 'pts_half_ppr': 1.5, 'idp_tkl_solo': 1.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 2.0, 'humidity': 348.0, 'gp': 6.0, 'gms_active': 6.0, 'def_snp': 15.0}
# Isaiah Searight {'wind_speed': 136.0, 'tm_st_snp': 370.0, 'tm_off_snp': 1007.0, 'tm_def_snp': 1062.0, 'temperature': 848.0, 'humidity': 904.0, 'gp': 15.0}
# Olamide Zaccheaus {'wind_speed': 115.0, 'tm_st_snp': 353.0, 'tm_off_snp': 1101.0, 'tm_def_snp': 997.0, 'temperature': 978.0, 'td': 2.0, 'st_snp': 134.0, 'rec_ypt': 31.0, 'rec_ypr': 93.0, 'rec_yd': 93.0, 'rec_tgt': 3.0, 'rec_td_40p': 1.0, 'rec_td': 1.0, 'rec_pct': 50.0, 'rec_lng': 93.0, 'rec_40p': 1.0, 'rec': 1.0, 'pts_std': 15.3, 'pts_ppr': 16.3, 'pts_half_ppr': 15.8, 'off_snp': 74.0, 'idp_tkl_solo': 1.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 2.0, 'idp_fum_ret_yd': 3.0, 'idp_fum_rec': 1.0, 'idp_def_td': 1.0, 'humidity': 913.0, 'gp': 9.0, 'gms_active': 9.0, 'bonus_rec_wr': 1.0}
# Vic Beasley {'wind_speed': 115.0, 'tm_st_snp': 353.0, 'tm_off_snp': 1101.0, 'tm_def_snp': 997.0, 'temperature': 978.0, 'st_snp': 1.0, 'sack_yd': 69.0, 'pts_std': 87.4, 'pts_ppr': 87.4, 'pts_half_ppr': 87.4, 'idp_tkl_solo': 28.0, 'idp_tkl_loss': 11.0, 'idp_tkl_ast': 11.0, 'idp_tkl': 39.0, 'idp_sack': 8.0, 'idp_qb_hit': 12.0, 'idp_pass_def': 2.0, 'idp_ff': 2.0, 'humidity': 913.0, 'gs': 14.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 730.0}
# Zach Zenner {'wind_speed': 37.0, 'tm_st_snp': 172.0, 'tm_off_snp': 459.0, 'tm_def_snp': 527.0, 'temperature': 406.0, 'st_snp': 48.0, 'rush_ypa': -0.67, 'rush_yd': -2.0, 'rush_lng': -2.0, 'rush_att': 3.0, 'rec_ypt': 6.33, 'rec_ypr': 9.5, 'rec_yd': 19.0, 'rec_tgt': 3.0, 'rec_pct': 150.0, 'rec_lng': 19.0, 'rec_fd': 2.0, 'rec_5_9': 1.0, 'rec_10_19': 1.0, 'rec': 2.0, 'pts_std': 1.7, 'pts_ppr': 3.7, 'pts_half_ppr': 2.7, 'off_snp': 28.0, 'humidity': 305.0, 'gp': 5.0, 'gms_active': 5.0, 'bonus_rec_rb': 2.0}
# Brandon Knight {'wind_speed': 153.0, 'tm_st_snp': 297.0, 'tm_off_snp': 1055.0, 'tm_def_snp': 1039.0, 'temperature': 897.0, 'st_snp': 34.0, 'off_snp': 110.0, 'humidity': 948.0, 'gs': 1.0, 'gp': 6.0, 'gms_active': 6.0}
# Patrick Laird {'rec_yd': 156.0, 'off_snp': 232.0, 'gs': 3.0, 'gp': 14.0, 'tm_off_snp': 1017.0, 'wind_speed': 178.0, 'rec_ypt': 6.24, 'bonus_rec_rb': 19.0, 'rec_pct': 500.0, 'gms_active': 14.0, 'rec_ypr': 8.21, 'pts_half_ppr': 47.8, 'rec_20_29': 1.0, 'st_snp': 247.0, 'idp_tkl': 6.0, 'rec_0_4': 5.0, 'tm_def_snp': 1060.0, 'rush_ypa': 2.88, 'temperature': 1016.0, 'rush_fd': 6.0, 'rec_2pt': 1.0, 'rec': 19.0, 'idp_tkl_ast': 1.0, 'rec_5_9': 6.0, 'rush_att': 51.0, 'idp_tkl_solo': 5.0, 'td': 1.0, 'rush_lng': 68.0, 'rec_lng': 70.0, 'rec_10_19': 7.0, 'rec_tgt': 25.0, 'tm_st_snp': 370.0, 'rush_yd': 147.0, 'rush_td': 1.0, 'pts_ppr': 57.3, 'humidity': 894.0, 'pts_std': 38.3, 'rec_fd': 10.0}
# Brent Qvale {'wind_speed': 20.0, 'tm_st_snp': 96.0, 'tm_off_snp': 252.0, 'tm_def_snp': 282.0, 'temperature': 242.0, 'st_snp': 4.0, 'off_snp': 10.0, 'humidity': 229.0, 'gp': 1.0, 'gms_active': 1.0}
# Ryan Kelly {'wind_speed': 106.0, 'tm_st_snp': 333.0, 'tm_off_snp': 1036.0, 'tm_def_snp': 968.0, 'temperature': 922.0, 'off_snp': 977.0, 'idp_tkl_solo': 2.0, 'idp_tkl': 2.0, 'humidity': 939.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0}
# Kalan Reed {'wind_speed': 24.0, 'tm_st_snp': 79.0, 'tm_off_snp': 279.0, 'tm_def_snp': 255.0, 'temperature': 272.0, 'humidity': 325.0, 'gp': 4.0}
# Buster Skrine {'wind_speed': 130.0, 'tm_st_snp': 322.0, 'tm_off_snp': 1016.0, 'tm_def_snp': 1044.0, 'temperature': 706.0, 'st_snp': 112.0, 'pts_std': 54.5, 'pts_ppr': 54.5, 'pts_half_ppr': 54.5, 'idp_tkl_solo': 36.0, 'idp_tkl_loss': 1.5, 'idp_tkl_ast': 8.0, 'idp_tkl': 44.0, 'idp_qb_hit': 2.0, 'idp_pass_def': 5.0, 'idp_ff': 2.0, 'humidity': 611.0, 'gs': 4.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 712.0}
# Ryan Nall {'wind_speed': 79.0, 'tm_st_snp': 150.0, 'tm_off_snp': 494.0, 'tm_def_snp': 472.0, 'temperature': 283.0, 'st_snp': 122.0, 'off_snp': 4.0, 'idp_tkl_solo': 2.0, 'idp_tkl': 2.0, 'humidity': 222.0, 'gp': 7.0, 'gms_active': 7.0}
# Ted Ginn {'rec_yd': 411.0, 'off_snp': 602.0, 'gs': 9.0, 'rec_30_39': 2.0, 'bonus_rush_rec_yd_100': 1.0, 'gp': 15.0, 'tm_off_snp': 1014.0, 'wind_speed': 93.0, 'rec_ypt': 7.61, 'rec_pct': 696.7, 'gms_active': 15.0, 'rec_ypr': 14.17, 'pts_half_ppr': 69.4, 'rec_20_29': 3.0, 'st_snp': 9.0, 'rec_0_4': 5.0, 'tm_def_snp': 1012.0, 'rush_ypa': 6.0, 'temperature': 980.0, 'rush_fd': 2.0, 'rec': 29.0, 'rec_5_9': 8.0, 'rush_att': 3.0, 'td': 2.0, 'rec_td': 2.0, 'rush_lng': 18.0, 'rec_lng': 268.0, 'rec_10_19': 9.0, 'rec_tgt': 54.0, 'tm_st_snp': 346.0, 'rush_yd': 18.0, 'rec_40p': 2.0, 'bonus_rec_wr': 29.0, 'pts_ppr': 83.9, 'bonus_rec_yd_100': 1.0, 'humidity': 988.0, 'pts_std': 54.9, 'rec_fd': 17.0, 'kr': 1.0}
# Brandon Thomas {'wind_speed': 95.0, 'tm_st_snp': 262.0, 'tm_off_snp': 775.0, 'tm_def_snp': 744.0, 'temperature': 656.0, 'humidity': 722.0, 'gp': 11.0}
# Joshua Dobbs {'wind_speed': 122.0, 'tm_st_snp': 358.0, 'tm_off_snp': 1050.0, 'tm_def_snp': 1015.0, 'temperature': 934.0, 'humidity': 990.0, 'gp': 15.0, 'gms_active': 8.0}
# Ethan Greenidge {'wind_speed': 93.0, 'tm_st_snp': 346.0, 'tm_off_snp': 1014.0, 'tm_def_snp': 1012.0, 'temperature': 980.0, 'humidity': 988.0, 'gp': 15.0, 'gms_active': 2.0}
# Byron Murphy {'wind_speed': 79.0, 'tm_st_snp': 373.0, 'tm_off_snp': 997.0, 'tm_def_snp': 1078.0, 'temperature': 993.0, 'st_snp': 21.0, 'pts_std': 79.5, 'pts_ppr': 79.5, 'pts_half_ppr': 79.5, 'idp_tkl_solo': 62.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 9.0, 'idp_tkl': 71.0, 'idp_pass_def': 9.0, 'idp_int': 1.0, 'humidity': 982.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 1050.0}
# Dylan Cole {'wind_speed': 119.0, 'tm_st_snp': 317.0, 'tm_off_snp': 1030.0, 'tm_def_snp': 1028.0, 'temperature': 1024.0, 'st_snp': 185.0, 'pts_std': 18.5, 'pts_ppr': 18.5, 'pts_half_ppr': 18.5, 'idp_tkl_solo': 13.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 16.0, 'idp_pass_def': 1.0, 'idp_fum_ret_yd': 26.0, 'idp_fum_rec': 1.0, 'humidity': 1011.0, 'gp': 11.0, 'gms_active': 11.0, 'def_snp': 139.0}
# Shy Tuttle {'wind_speed': 93.0, 'tm_st_snp': 346.0, 'tm_off_snp': 1014.0, 'tm_def_snp': 1012.0, 'temperature': 980.0, 'st_snp': 31.0, 'sack_yd': 8.0, 'pts_std': 33.3, 'pts_ppr': 33.3, 'pts_half_ppr': 33.3, 'idp_tkl_solo': 8.0, 'idp_tkl_loss': 4.0, 'idp_tkl_ast': 11.0, 'idp_tkl': 19.0, 'idp_sack': 2.5, 'idp_qb_hit': 5.0, 'idp_pass_def': 2.0, 'idp_int_ret_yd': 19.0, 'idp_int': 1.0, 'humidity': 988.0, 'gs': 1.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 318.0}
# Greg Olsen {'rec_yd': 585.0, 'off_snp': 779.0, 'gs': 13.0, 'rec_30_39': 1.0, 'bonus_rush_rec_yd_100': 1.0, 'gp': 13.0, 'tm_off_snp': 1060.0, 'wind_speed': 104.0, 'rec_ypt': 7.7, 'bonus_rec_te': 50.0, 'rec_pct': 845.3, 'gms_active': 13.0, 'rec_ypr': 11.7, 'pts_half_ppr': 95.5, 'rec_20_29': 4.0, 'st_snp': 2.0, 'rec_0_4': 9.0, 'tm_def_snp': 1058.0, 'temperature': 900.0, 'rec': 50.0, 'rec_5_9': 17.0, 'td': 2.0, 'rec_td': 2.0, 'rec_lng': 223.0, 'rec_10_19': 18.0, 'rec_tgt': 76.0, 'tm_st_snp': 389.0, 'rec_40p': 1.0, 'pts_ppr': 120.5, 'bonus_rec_yd_100': 1.0, 'humidity': 748.0, 'pts_std': 70.5, 'rec_fd': 32.0}
# Al Woods {'wind_speed': 87.0, 'tm_st_snp': 280.0, 'tm_off_snp': 992.0, 'tm_def_snp': 975.0, 'temperature': 791.0, 'st_snp': 31.0, 'sack_yd': 5.0, 'pts_std': 37.5, 'pts_ppr': 37.5, 'pts_half_ppr': 37.5, 'idp_tkl_solo': 16.0, 'idp_tkl_loss': 4.0, 'idp_tkl_ast': 16.0, 'idp_tkl': 32.0, 'idp_sack': 1.0, 'idp_qb_hit': 1.0, 'idp_fum_ret_yd': 5.0, 'idp_fum_rec': 2.0, 'humidity': 744.0, 'gs': 5.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 459.0}
# Brady Sheldon {'wind_speed': 27.0, 'tm_st_snp': 33.0, 'tm_off_snp': 90.0, 'tm_def_snp': 90.0, 'temperature': 76.0, 'humidity': 100.0, 'gp': 1.0}
# Garrett Dickerson {'wind_speed': 27.0, 'tm_st_snp': 70.0, 'tm_off_snp': 190.0, 'tm_def_snp': 218.0, 'temperature': 171.0, 'st_snp': 6.0, 'off_snp': 3.0, 'humidity': 244.0, 'gp': 2.0, 'gms_active': 2.0}
# AJ Green {'wind_speed': 129.0, 'tm_st_snp': 357.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1036.0, 'temperature': 880.0, 'humidity': 1028.0, 'gp': 15.0}
# Derick Roberson {'wind_speed': 30.0, 'tm_st_snp': 97.0, 'tm_off_snp': 251.0, 'tm_def_snp': 268.0, 'temperature': 186.0, 'st_snp': 21.0, 'sack_yd': 15.0, 'pts_std': 12.5, 'pts_ppr': 12.5, 'pts_half_ppr': 12.5, 'idp_tkl_solo': 3.0, 'idp_tkl_loss': 2.0, 'idp_tkl': 3.0, 'idp_sack': 2.0, 'idp_qb_hit': 2.0, 'humidity': 274.0, 'gp': 2.0, 'gms_active': 2.0, 'def_snp': 13.0}
# Quinton Spain {'wind_speed': 127.0, 'tm_st_snp': 278.0, 'tm_off_snp': 1033.0, 'tm_def_snp': 986.0, 'temperature': 816.0, 'st_snp': 60.0, 'off_snp': 1028.0, 'idp_tkl_solo': 3.0, 'idp_tkl': 3.0, 'humidity': 874.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0}
# Daniel Helm {'wind_speed': 9.0, 'tm_st_snp': 51.0, 'tm_off_snp': 121.0, 'tm_def_snp': 137.0, 'temperature': 102.0, 'humidity': 72.0, 'gp': 2.0, 'gms_active': 1.0}
# Genard Avery {'wind_speed': 137.0, 'tm_st_snp': 349.0, 'tm_off_snp': 1018.0, 'tm_def_snp': 915.0, 'temperature': 787.0, 'st_snp': 132.0, 'sack_yd': 5.5, 'pts_std': 6.05, 'pts_ppr': 6.05, 'pts_half_ppr': 6.0, 'idp_tkl_solo': 2.0, 'idp_tkl_loss': 0.5, 'idp_tkl_ast': 2.0, 'idp_tkl': 4.0, 'idp_sack': 0.5, 'idp_qb_hit': 1.0, 'humidity': 650.0, 'gp': 9.0, 'gms_active': 9.0, 'def_snp': 29.0}
# Andre Chachere {'wind_speed': 6.0, 'tm_st_snp': 26.0, 'tm_off_snp': 69.0, 'tm_def_snp': 57.0, 'temperature': 40.0, 'humidity': 100.0, 'gp': 1.0}
# Ben Burr-Kirven {'wind_speed': 93.0, 'tm_st_snp': 307.0, 'tm_off_snp': 1049.0, 'tm_def_snp': 1044.0, 'temperature': 831.0, 'st_snp': 290.0, 'pts_std': 8.5, 'pts_ppr': 8.5, 'pts_half_ppr': 8.5, 'idp_tkl_solo': 3.0, 'idp_tkl_ast': 5.0, 'idp_tkl': 8.0, 'idp_ff': 1.0, 'humidity': 844.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 4.0}
# T.J. Edwards {'wind_speed': 160.0, 'tm_st_snp': 359.0, 'tm_off_snp': 1110.0, 'tm_def_snp': 963.0, 'temperature': 874.0, 'st_snp': 303.0, 'pts_std': 21.5, 'pts_ppr': 21.5, 'pts_half_ppr': 21.5, 'idp_tkl_solo': 15.0, 'idp_tkl_loss': 0.5, 'idp_tkl_ast': 12.0, 'idp_tkl': 27.0, 'humidity': 898.0, 'gs': 4.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 109.0}
# Zach Ertz {'rec_yd': 916.0, 'off_snp': 953.0, 'gs': 15.0, 'rec_30_39': 1.0, 'bonus_rush_rec_yd_100': 1.0, 'gp': 15.0, 'tm_off_snp': 1110.0, 'wind_speed': 160.0, 'rec_ypt': 6.79, 'bonus_rec_te': 88.0, 'rec_pct': 950.3, 'gms_active': 15.0, 'rec_ypr': 10.41, 'pts_half_ppr': 171.6, 'rec_20_29': 11.0, 'st_snp': 3.0, 'rec_0_4': 15.0, 'tm_def_snp': 963.0, 'temperature': 874.0, 'rec_2pt': 1.0, 'rec': 88.0, 'rec_5_9': 34.0, 'td': 6.0, 'rec_td': 6.0, 'rec_lng': 303.0, 'rec_10_19': 27.0, 'rec_tgt': 135.0, 'tm_st_snp': 359.0, 'pts_ppr': 215.6, 'bonus_rec_yd_100': 1.0, 'fum_lost': 1.0, 'humidity': 898.0, 'fum': 1.0, 'pts_std': 127.6, 'rec_fd': 46.0}
# Tyler Shatley {'wind_speed': 122.0, 'tm_st_snp': 363.0, 'tm_off_snp': 1039.0, 'tm_def_snp': 1013.0, 'temperature': 976.0, 'st_snp': 32.0, 'off_snp': 19.0, 'humidity': 1029.0, 'gp': 15.0, 'gms_active': 15.0}
# Angelo Blackson {'wind_speed': 119.0, 'tm_st_snp': 317.0, 'tm_off_snp': 1030.0, 'tm_def_snp': 1028.0, 'temperature': 1024.0, 'st_snp': 65.0, 'pts_std': 17.5, 'pts_ppr': 17.5, 'pts_half_ppr': 17.5, 'idp_tkl_solo': 11.0, 'idp_tkl_loss': 1.5, 'idp_tkl_ast': 8.0, 'idp_tkl': 19.0, 'idp_qb_hit': 1.0, 'idp_blk_kick': 2.0, 'humidity': 1011.0, 'gs': 14.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 412.0}
# Cam Newton {'pass_int': 1.0, 'pass_lng': 61.0, 'off_snp': 146.0, 'gs': 2.0, 'cmp_pct': 114.8, 'pass_fd': 30.0, 'gp': 2.0, 'pass_sack': 6.0, 'tm_off_snp': 548.0, 'wind_speed': 47.0, 'bonus_pass_cmp_25': 2.0, 'gms_active': 2.0, 'pass_cmp': 50.0, 'pts_half_ppr': 16.7, 'pass_rtg': 142.29, 'idp_tkl': 1.0, 'pass_sack_yds': 43.0, 'tm_def_snp': 592.0, 'rush_ypa': -0.4, 'temperature': 576.0, 'bonus_pass_yd_300': 1.0, 'pass_att': 89.0, 'pass_inc': 39.0, 'pass_cmp_40p': 2.0, 'pass_ypa': 6.43, 'rush_att': 5.0, 'idp_tkl_solo': 1.0, 'rush_lng': 3.0, 'tm_st_snp': 213.0, 'rush_yd': -2.0, 'pass_yd': 572.0, 'pts_ppr': 16.68, 'fum_lost': 2.0, 'humidity': 522.0, 'fum': 2.0, 'pts_std': 16.68, 'pass_ypc': 11.44}
# Eric Murray {'wind_speed': 125.0, 'tm_st_snp': 346.0, 'tm_off_snp': 1016.0, 'tm_def_snp': 1019.0, 'temperature': 779.0, 'st_snp': 73.0, 'sack_yd': 4.0, 'pts_std': 26.9, 'pts_ppr': 26.9, 'pts_half_ppr': 26.9, 'idp_tkl_solo': 15.0, 'idp_tkl_loss': 3.5, 'idp_tkl_ast': 8.0, 'idp_tkl': 23.0, 'idp_sack': 1.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 1.0, 'humidity': 717.0, 'gs': 3.0, 'gp': 8.0, 'gms_active': 8.0, 'def_snp': 322.0}
# Desmond King {'def_snp': 583.0, 'kr_yd': 318.0, 'gs': 8.0, 'sack_yd': 12.0, 'idp_ff': 1.0, 'gp': 14.0, 'tm_off_snp': 994.0, 'wind_speed': 112.0, 'gms_active': 14.0, 'pts_half_ppr': 73.2, 'pr_ypa': 5.62, 'idp_qb_hit': 5.0, 'st_snp': 197.0, 'pr': 21.0, 'idp_tkl': 50.0, 'kr_ypa': 21.2, 'tm_def_snp': 934.0, 'pr_lng': 100.0, 'temperature': 938.0, 'idp_pass_def': 2.0, 'idp_tkl_loss': 5.5, 'kr_lng': 243.0, 'pr_td': 1.0, 'idp_fum_rec': 1.0, 'idp_sack': 2.5, 'st_td': 1.0, 'idp_tkl_ast': 11.0, 'idp_tkl_solo': 39.0, 'td': 1.0, 'tm_st_snp': 334.0, 'pr_yd': 118.0, 'idp_fum_ret_yd': 13.0, 'pts_ppr': 73.2, 'fum_lost': 1.0, 'humidity': 910.0, 'fum': 4.0, 'pts_std': 73.2, 'kr': 15.0}
# Fabian Moreau {'wind_speed': 124.0, 'tm_st_snp': 352.0, 'tm_off_snp': 899.0, 'tm_def_snp': 1070.0, 'temperature': 834.0, 'st_snp': 16.0, 'pts_std': 53.0, 'pts_ppr': 53.0, 'pts_half_ppr': 53.0, 'idp_tkl_solo': 33.0, 'idp_tkl_loss': 0.5, 'idp_tkl_ast': 11.0, 'idp_tkl': 44.0, 'idp_pass_def': 5.0, 'idp_int_ret_yd': 16.0, 'idp_int': 3.0, 'humidity': 676.0, 'gs': 7.0, 'gp': 12.0, 'gms_active': 12.0, 'def_snp': 673.0}
# James White {'kr_yd': 41.0, 'pass_lng': 35.0, 'rec_yd': 612.0, 'off_snp': 471.0, 'gs': 1.0, 'cmp_pct': 100.0, 'rec_30_39': 3.0, 'pass_fd': 1.0, 'bonus_rush_rec_yd_100': 1.0, 'gp': 14.0, 'tm_off_snp': 1098.0, 'wind_speed': 129.0, 'rec_ypt': 6.65, 'bonus_rec_rb': 69.0, 'rec_pct': 1016.8, 'gms_active': 14.0, 'pass_cmp': 1.0, 'rec_ypr': 8.87, 'pts_half_ppr': 155.0, 'pass_rtg': 118.75, 'rec_20_29': 5.0, 'st_snp': 45.0, 'idp_tkl': 2.0, 'rec_0_4': 20.0, 'kr_ypa': 20.5, 'tm_def_snp': 934.0, 'rush_ypa': 3.98, 'temperature': 768.0, 'rush_fd': 14.0, 'kr_lng': 41.0, 'pass_att': 1.0, 'rec': 69.0, 'pass_ypa': 35.0, 'rec_5_9': 24.0, 'rush_att': 65.0, 'idp_tkl_solo': 2.0, 'td': 5.0, 'rush_2pt': 1.0, 'rec_td': 4.0, 'rush_lng': 117.0, 'rec_lng': 308.0, 'rec_10_19': 11.0, 'rec_tgt': 92.0, 'tm_st_snp': 348.0, 'rush_yd': 259.0, 'rec_40p': 1.0, 'pass_yd': 35.0, 'rush_td': 1.0, 'pts_ppr': 189.5, 'humidity': 758.0, 'pts_std': 120.5, 'pass_ypc': 35.0, 'rec_fd': 26.0, 'kr': 2.0}
# Ira Lewis {'wind_speed': 119.0, 'tm_st_snp': 317.0, 'tm_off_snp': 1030.0, 'tm_def_snp': 1028.0, 'temperature': 1024.0, 'humidity': 1011.0, 'gp': 15.0}
# Dontrell Hilliard {'kr_yd': 421.0, 'rec_yd': 92.0, 'off_snp': 134.0, 'gp': 14.0, 'tm_off_snp': 1016.0, 'wind_speed': 125.0, 'rec_ypt': 6.13, 'bonus_rec_rb': 12.0, 'rec_pct': 483.4, 'gms_active': 14.0, 'rec_ypr': 7.67, 'pts_half_ppr': 32.1, 'pr_ypa': 6.69, 'st_snp': 224.0, 'pr': 16.0, 'idp_tkl': 11.0, 'rec_0_4': 5.0, 'kr_ypa': 24.76, 'tm_def_snp': 1019.0, 'pr_lng': 86.0, 'rush_ypa': 3.77, 'temperature': 779.0, 'rush_fd': 1.0, 'kr_lng': 218.0, 'rec': 12.0, 'idp_tkl_ast': 3.0, 'rec_5_9': 3.0, 'rush_att': 13.0, 'idp_tkl_solo': 8.0, 'td': 2.0, 'rush_lng': 29.0, 'rec_lng': 69.0, 'rec_10_19': 4.0, 'rec_tgt': 15.0, 'tm_st_snp': 346.0, 'rush_yd': 49.0, 'pr_yd': 107.0, 'rush_td': 2.0, 'pts_ppr': 38.1, 'humidity': 717.0, 'fum': 2.0, 'pts_std': 26.1, 'rec_fd': 4.0, 'kr': 17.0}
# Kyle Shurmur {'wind_speed': 21.0, 'tm_st_snp': 49.0, 'tm_off_snp': 119.0, 'tm_def_snp': 140.0, 'temperature': 98.0, 'humidity': 86.0, 'gp': 2.0, 'gms_active': 1.0}
# Cethan Carter {'wind_speed': 129.0, 'tm_st_snp': 357.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1036.0, 'temperature': 880.0, 'td': 1.0, 'st_snp': 278.0, 'rec_ypt': 6.5, 'rec_ypr': 6.5, 'rec_yd': 13.0, 'rec_tgt': 2.0, 'rec_td': 1.0, 'rec_pct': 100.0, 'rec_lng': 8.0, 'rec_fd': 1.0, 'rec_5_9': 2.0, 'rec': 2.0, 'pts_std': 7.3, 'pts_ppr': 9.3, 'pts_half_ppr': 8.3, 'off_snp': 75.0, 'idp_tkl_solo': 3.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 6.0, 'humidity': 1028.0, 'gp': 14.0, 'gms_active': 14.0, 'bonus_rec_te': 2.0}
# Ryan Neal {'wind_speed': 10.0, 'tm_st_snp': 46.0, 'tm_off_snp': 124.0, 'tm_def_snp': 141.0, 'temperature': 90.0, 'st_snp': 25.0, 'pts_std': 1.0, 'pts_ppr': 1.0, 'pts_half_ppr': 1.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 136.0, 'gp': 2.0, 'gms_active': 2.0}
# Ross Travis {'wind_speed': 34.0, 'tm_st_snp': 91.0, 'tm_off_snp': 255.0, 'tm_def_snp': 275.0, 'temperature': 219.0, 'rec_ypt': 8.5, 'rec_ypr': 12.75, 'rec_yd': 51.0, 'rec_tgt': 6.0, 'rec_pct': 216.7, 'rec_lng': 45.0, 'rec_fd': 2.0, 'rec_5_9': 1.0, 'rec_20_29': 1.0, 'rec_10_19': 1.0, 'rec_0_4': 1.0, 'rec': 4.0, 'pts_std': 3.1, 'pts_ppr': 7.1, 'pts_half_ppr': 5.1, 'off_snp': 23.0, 'humidity': 286.0, 'gs': 1.0, 'gp': 3.0, 'gms_active': 3.0, 'fum_lost': 1.0, 'fum': 1.0, 'bonus_rec_te': 4.0}
# Jeremy Reaves {'wind_speed': 87.0, 'tm_st_snp': 237.0, 'tm_off_snp': 581.0, 'tm_def_snp': 703.0, 'temperature': 460.0, 'st_snp': 178.0, 'pts_std': 5.5, 'pts_ppr': 5.5, 'pts_half_ppr': 5.5, 'idp_tkl_solo': 4.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 7.0, 'humidity': 389.0, 'gp': 8.0, 'gms_active': 8.0, 'def_snp': 35.0}
# Carl Nassib {'wind_speed': 122.0, 'tm_st_snp': 377.0, 'tm_off_snp': 1108.0, 'tm_def_snp': 1077.0, 'temperature': 952.0, 'st_snp': 42.0, 'sack_yd': 25.0, 'pts_std': 64.5, 'pts_ppr': 64.5, 'pts_half_ppr': 64.5, 'idp_tkl_solo': 22.0, 'idp_tkl_loss': 9.0, 'idp_tkl_ast': 8.0, 'idp_tkl': 30.0, 'idp_sack': 6.0, 'idp_qb_hit': 9.0, 'idp_fum_rec': 1.0, 'idp_ff': 1.0, 'humidity': 945.0, 'gs': 8.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 606.0}
# Taybor Pepper {'wind_speed': 178.0, 'tm_st_snp': 370.0, 'tm_off_snp': 1017.0, 'tm_def_snp': 1060.0, 'temperature': 1016.0, 'st_snp': 128.0, 'humidity': 894.0, 'gp': 15.0, 'gms_active': 15.0}
# Younghoe Koo {'xpmiss': 1.0, 'xpm': 14.0, 'xpa': 15.0, 'wind_speed': 60.0, 'tm_st_snp': 161.0, 'tm_off_snp': 538.0, 'tm_def_snp': 449.0, 'temperature': 354.0, 'st_snp': 71.0, 'st_fum_rec': 1.0, 'pts_std': 70.0, 'pts_ppr': 70.0, 'pts_half_ppr': 70.0, 'off_snp': 10.0, 'humidity': 333.0, 'gp': 7.0, 'gms_active': 7.0, 'fgmiss_40_49': 2.0, 'fgmiss_30_39': 1.0, 'fgmiss': 3.0, 'fgm_yds_over_30': 130.0, 'fgm_yds': 649.0, 'fgm_pct': 591.7, 'fgm_lng': 287.0, 'fgm_50p': 1.0, 'fgm_40_49': 5.0, 'fgm_30_39': 7.0, 'fgm_20_29': 5.0, 'fgm': 18.0, 'fga': 21.0}
# Tytus Howard {'wind_speed': 119.0, 'tm_st_snp': 317.0, 'tm_off_snp': 1030.0, 'tm_def_snp': 1028.0, 'temperature': 1024.0, 'st_snp': 36.0, 'off_snp': 502.0, 'humidity': 1011.0, 'gs': 8.0, 'gp': 8.0, 'gms_active': 8.0}
# Joel Bitonio {'wind_speed': 125.0, 'tm_st_snp': 346.0, 'tm_off_snp': 1016.0, 'tm_def_snp': 1019.0, 'temperature': 779.0, 'st_snp': 61.0, 'off_snp': 1016.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 717.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0}
# Robert Woods {'rec_yd': 1067.0, 'off_snp': 932.0, 'gs': 10.0, 'rec_30_39': 3.0, 'bonus_rush_rec_yd_100': 4.0, 'gp': 14.0, 'tm_off_snp': 1052.0, 'wind_speed': 102.0, 'rec_ypt': 8.4, 'rec_pct': 910.1, 'gms_active': 14.0, 'rec_ypr': 12.86, 'pts_half_ppr': 170.8, 'rec_20_29': 9.0, 'st_snp': 2.0, 'idp_tkl': 3.0, 'rec_0_4': 11.0, 'tm_def_snp': 1042.0, 'rush_ypa': 6.63, 'temperature': 924.0, 'rush_fd': 4.0, 'rec': 83.0, 'idp_tkl_ast': 1.0, 'rec_5_9': 19.0, 'rush_att': 16.0, 'idp_tkl_solo': 2.0, 'td': 2.0, 'rec_td': 1.0, 'rush_lng': 88.0, 'rec_lng': 334.0, 'rec_10_19': 38.0, 'rec_tgt': 127.0, 'tm_st_snp': 371.0, 'rush_yd': 106.0, 'rec_40p': 1.0, 'rush_td': 1.0, 'bonus_rec_wr': 83.0, 'pts_ppr': 212.3, 'bonus_rec_yd_100': 3.0, 'humidity': 720.0, 'pts_std': 129.3, 'rec_fd': 50.0}
# Jamal Adams {'wind_speed': 115.0, 'tm_st_snp': 368.0, 'tm_off_snp': 968.0, 'tm_def_snp': 1059.0, 'temperature': 821.0, 'td': 2.0, 'st_snp': 42.0, 'sack_yd': 46.5, 'pts_std': 139.15, 'pts_ppr': 139.15, 'pts_half_ppr': 139.1, 'idp_tkl_solo': 58.0, 'idp_tkl_loss': 13.5, 'idp_tkl_ast': 14.0, 'idp_tkl': 72.0, 'idp_sack': 6.5, 'idp_qb_hit': 13.0, 'idp_pass_def': 6.0, 'idp_int_ret_yd': 61.0, 'idp_int': 1.0, 'idp_fum_ret_yd': 25.0, 'idp_fum_rec': 1.0, 'idp_ff': 2.0, 'idp_def_td': 2.0, 'humidity': 795.0, 'gs': 13.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 914.0}
# Josh Robinson {'wind_speed': 122.0, 'tm_st_snp': 363.0, 'tm_off_snp': 1039.0, 'tm_def_snp': 1013.0, 'temperature': 976.0, 'st_snp': 192.0, 'pts_std': 2.5, 'pts_ppr': 2.5, 'pts_half_ppr': 2.5, 'idp_tkl_solo': 2.0, 'idp_tkl_ast': 1.0, 'idp_tkl': 3.0, 'humidity': 1029.0, 'gp': 8.0, 'gms_active': 8.0}
# Marquise Blair {'wind_speed': 93.0, 'tm_st_snp': 307.0, 'tm_off_snp': 1049.0, 'tm_def_snp': 1044.0, 'temperature': 831.0, 'st_snp': 193.0, 'pts_std': 31.0, 'pts_ppr': 31.0, 'pts_half_ppr': 31.0, 'idp_tkl_solo': 22.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 8.0, 'idp_tkl': 30.0, 'idp_pass_def': 1.0, 'idp_ff': 1.0, 'humidity': 844.0, 'gs': 3.0, 'gp': 13.0, 'gms_active': 13.0, 'def_snp': 233.0}
# Travis Carrie {'wind_speed': 125.0, 'tm_st_snp': 346.0, 'tm_off_snp': 1016.0, 'tm_def_snp': 1019.0, 'temperature': 779.0, 'st_snp': 66.0, 'sack_yd': 3.0, 'pts_std': 67.3, 'pts_ppr': 67.3, 'pts_half_ppr': 67.3, 'idp_tkl_solo': 40.0, 'idp_tkl_loss': 4.0, 'idp_tkl_ast': 12.0, 'idp_tkl': 52.0, 'idp_sack': 1.0, 'idp_qb_hit': 2.0, 'idp_pass_def': 4.0, 'idp_int': 1.0, 'idp_fum_ret_yd': 4.0, 'idp_fum_rec': 1.0, 'idp_ff': 1.0, 'humidity': 717.0, 'gs': 6.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 693.0}
# Daniel Ekuale {'wind_speed': 89.0, 'tm_st_snp': 274.0, 'tm_off_snp': 802.0, 'tm_def_snp': 823.0, 'temperature': 563.0, 'st_snp': 5.0, 'pts_std': 5.0, 'pts_ppr': 5.0, 'pts_half_ppr': 5.0, 'idp_tkl_solo': 3.0, 'idp_tkl_loss': 1.5, 'idp_tkl_ast': 1.0, 'idp_tkl': 4.0, 'humidity': 539.0, 'gp': 4.0, 'gms_active': 4.0, 'def_snp': 69.0}
# Ryan Griffin {'wind_speed': 122.0, 'tm_st_snp': 377.0, 'tm_off_snp': 1108.0, 'tm_def_snp': 1077.0, 'temperature': 952.0, 'rush_ypa': -0.25, 'rush_yd': -1.0, 'rush_att': 4.0, 'pts_std': 0.62, 'pts_ppr': 0.62, 'pts_half_ppr': 0.6, 'pass_ypc': 9.0, 'pass_ypa': 4.5, 'pass_yd': 18.0, 'pass_rtg': 62.5, 'pass_lng': 13.0, 'pass_inc': 2.0, 'pass_fd': 1.0, 'pass_cmp': 2.0, 'pass_att': 4.0, 'off_snp': 10.0, 'humidity': 945.0, 'gp': 2.0, 'gms_active': 15.0, 'cmp_pct': 50.0}
# Tony Pollard {'kr_yd': 188.0, 'rec_yd': 102.0, 'off_snp': 177.0, 'bonus_rush_yd_100': 2.0, 'bonus_rush_rec_yd_100': 2.0, 'gp': 14.0, 'tm_off_snp': 1055.0, 'rush_40p': 1.0, 'wind_speed': 153.0, 'rec_ypt': 5.67, 'bonus_rec_rb': 14.0, 'rec_pct': 508.3, 'gms_active': 14.0, 'rec_ypr': 7.29, 'pts_half_ppr': 74.7, 'rec_20_29': 1.0, 'st_snp': 108.0, 'idp_tkl': 1.0, 'rec_0_4': 4.0, 'kr_ypa': 15.67, 'tm_def_snp': 1039.0, 'rush_ypa': 5.49, 'temperature': 897.0, 'rush_fd': 16.0, 'kr_lng': 93.0, 'rec': 14.0, 'rec_5_9': 6.0, 'rush_att': 72.0, 'idp_tkl_solo': 1.0, 'td': 3.0, 'rush_2pt': 1.0, 'rec_td': 1.0, 'rush_lng': 142.0, 'rec_lng': 61.0, 'rush_td_40p': 1.0, 'rec_10_19': 2.0, 'rec_tgt': 18.0, 'tm_st_snp': 297.0, 'rush_yd': 395.0, 'rush_td': 2.0, 'pts_ppr': 81.7, 'fum_lost': 1.0, 'humidity': 948.0, 'fum': 1.0, 'pts_std': 67.7, 'rec_fd': 3.0, 'kr': 12.0}
# Robbie Gould {'xpmiss': 1.0, 'xpm': 39.0, 'xpa': 40.0, 'wind_speed': 67.0, 'tm_st_snp': 329.0, 'tm_off_snp': 1036.0, 'tm_def_snp': 946.0, 'temperature': 929.0, 'st_snp': 65.0, 'pts_std': 102.0, 'pts_ppr': 102.0, 'pts_half_ppr': 102.0, 'off_snp': 8.0, 'humidity': 886.0, 'gp': 12.0, 'gms_active': 12.0, 'fgmiss_50p': 4.0, 'fgmiss_40_49': 2.0, 'fgmiss_30_39': 2.0, 'fgmiss': 8.0, 'fgm_yds_over_30': 97.0, 'fgm_yds': 682.0, 'fgm_pct': 858.4, 'fgm_lng': 388.0, 'fgm_40_49': 5.0, 'fgm_30_39': 7.0, 'fgm_20_29': 9.0, 'fgm': 21.0, 'fga': 29.0, 'fg_blkd': 2.0}
# Isaiah Wharton {'wind_speed': 22.0, 'tm_st_snp': 79.0, 'tm_off_snp': 243.0, 'tm_def_snp': 283.0, 'temperature': 250.0, 'humidity': 349.0, 'gp': 4.0}
# Steve Longa {'wind_speed': 73.0, 'tm_st_snp': 221.0, 'tm_off_snp': 618.0, 'tm_def_snp': 618.0, 'temperature': 374.0, 'st_snp': 164.0, 'pts_std': 8.5, 'pts_ppr': 8.5, 'pts_half_ppr': 8.5, 'idp_tkl_solo': 5.0, 'idp_tkl_ast': 7.0, 'idp_tkl': 12.0, 'humidity': 279.0, 'gp': 9.0, 'gms_active': 9.0, 'def_snp': 41.0}
# Breeland Speaks {'wind_speed': 36.0, 'tm_st_snp': 92.0, 'tm_off_snp': 282.0, 'tm_def_snp': 283.0, 'temperature': 294.0, 'humidity': 329.0, 'gp': 4.0}
# Matt Breida {'rec_yd': 120.0, 'off_snp': 251.0, 'gs': 5.0, 'bonus_rush_yd_100': 2.0, 'bonus_rush_rec_yd_100': 2.0, 'gp': 12.0, 'tm_off_snp': 1036.0, 'rush_40p': 1.0, 'wind_speed': 67.0, 'rec_ypt': 5.71, 'bonus_rec_rb': 19.0, 'rec_pct': 966.7, 'gms_active': 12.0, 'rec_ypr': 6.32, 'pts_half_ppr': 92.2, 'st_snp': 38.0, 'idp_tkl': 1.0, 'rec_0_4': 6.0, 'tm_def_snp': 946.0, 'rush_ypa': 5.1, 'temperature': 929.0, 'rush_fd': 23.0, 'rec': 19.0, 'rec_5_9': 7.0, 'rush_att': 119.0, 'idp_tkl_solo': 1.0, 'td': 2.0, 'rec_td': 1.0, 'rush_lng': 252.0, 'rec_lng': 89.0, 'rush_td_40p': 1.0, 'rec_10_19': 5.0, 'rec_tgt': 21.0, 'tm_st_snp': 329.0, 'rush_yd': 607.0, 'rush_td': 1.0, 'pts_ppr': 101.7, 'fum_lost': 1.0, 'humidity': 886.0, 'fum': 2.0, 'pts_std': 82.7, 'rec_fd': 5.0}
# Jack Cichy {'wind_speed': 122.0, 'tm_st_snp': 377.0, 'tm_off_snp': 1108.0, 'tm_def_snp': 1077.0, 'temperature': 952.0, 'st_snp': 78.0, 'humidity': 945.0, 'gp': 4.0, 'gms_active': 4.0, 'def_snp': 1.0}
# Nick Dzubnar {'wind_speed': 112.0, 'tm_st_snp': 334.0, 'tm_off_snp': 994.0, 'tm_def_snp': 934.0, 'temperature': 938.0, 'st_snp': 313.0, 'pts_std': 5.0, 'pts_ppr': 5.0, 'pts_half_ppr': 5.0, 'idp_tkl_solo': 3.0, 'idp_tkl_ast': 4.0, 'idp_tkl': 7.0, 'humidity': 910.0, 'gp': 15.0, 'gms_active': 15.0}
# Duke Shelley {'wind_speed': 130.0, 'tm_st_snp': 322.0, 'tm_off_snp': 1016.0, 'tm_def_snp': 1044.0, 'temperature': 706.0, 'st_snp': 44.0, 'humidity': 611.0, 'gp': 8.0, 'gms_active': 8.0, 'def_snp': 8.0}
# Demarcus Robinson {'rec_yd': 425.0, 'off_snp': 724.0, 'gs': 10.0, 'rec_30_39': 1.0, 'bonus_rush_rec_yd_100': 1.0, 'gp': 15.0, 'tm_off_snp': 1012.0, 'wind_speed': 147.0, 'rec_ypt': 8.02, 'rec_pct': 776.1, 'gms_active': 15.0, 'rec_ypr': 13.71, 'pts_half_ppr': 76.0, 'rec_20_29': 3.0, 'st_snp': 61.0, 'idp_tkl': 2.0, 'rec_0_4': 3.0, 'tm_def_snp': 1043.0, 'temperature': 794.0, 'rec': 31.0, 'rec_5_9': 12.0, 'idp_tkl_solo': 2.0, 'td': 3.0, 'rec_td': 3.0, 'rec_lng': 177.0, 'rec_td_40p': 1.0, 'rec_10_19': 10.0, 'rec_tgt': 53.0, 'tm_st_snp': 325.0, 'rec_40p': 2.0, 'bonus_rec_wr': 31.0, 'pts_ppr': 91.5, 'bonus_rec_yd_100': 1.0, 'humidity': 867.0, 'pts_std': 60.5, 'rec_fd': 16.0}
# Kyron Brown {'wind_speed': 51.0, 'tm_st_snp': 142.0, 'tm_off_snp': 399.0, 'tm_def_snp': 395.0, 'temperature': 226.0, 'st_snp': 18.0, 'pts_std': 5.0, 'pts_ppr': 5.0, 'pts_half_ppr': 5.0, 'off_snp': 6.0, 'idp_tkl_solo': 5.0, 'idp_tkl': 5.0, 'humidity': 226.0, 'gs': 1.0, 'gp': 3.0, 'gms_active': 3.0, 'def_snp': 53.0}
# ...
# Markus Golden {'wind_speed': 136.0, 'tm_st_snp': 370.0, 'tm_off_snp': 1007.0, 'tm_def_snp': 1062.0, 'temperature': 848.0, 'td': 1.0, 'st_snp': 22.0, 'sack_yd': 72.5, 'pts_std': 129.75, 'pts_ppr': 129.75, 'pts_half_ppr': 129.7, 'idp_tkl_solo': 35.0, 'idp_tkl_loss': 16.5, 'idp_tkl_ast': 30.0, 'idp_tkl': 65.0, 'idp_sack': 10.0, 'idp_qb_hit': 27.0, 'idp_fum_ret_yd': 42.0, 'idp_fum_rec': 1.0, 'idp_def_td': 1.0, 'humidity': 904.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 879.0}
# Kyle Juszczyk {'rec_yd': 190.0, 'off_snp': 362.0, 'gs': 11.0, 'gp': 11.0, 'tm_off_snp': 1036.0, 'wind_speed': 67.0, 'rec_ypt': 8.26, 'rec_pct': 566.7, 'gms_active': 11.0, 'rec_ypr': 10.0, 'pts_half_ppr': 35.2, 'rec_20_29': 3.0, 'st_snp': 36.0, 'rec_0_4': 6.0, 'tm_def_snp': 946.0, 'rush_ypa': 2.33, 'temperature': 929.0, 'rush_fd': 1.0, 'idp_fum_rec': 1.0, 'rec': 19.0, 'rec_5_9': 6.0, 'rush_att': 3.0, 'td': 1.0, 'rec_td': 1.0, 'rush_lng': 8.0, 'rec_lng': 105.0, 'rec_10_19': 4.0, 'rec_tgt': 23.0, 'tm_st_snp': 329.0, 'rush_yd': 7.0, 'idp_fum_ret_yd': 14.0, 'pts_ppr': 44.7, 'humidity': 886.0, 'pts_std': 25.7, 'rec_fd': 9.0}
# Brandon Marshall {'wind_speed': 3.0, 'tm_st_snp': 21.0, 'tm_off_snp': 72.0, 'tm_def_snp': 71.0, 'temperature': 64.0, 'humidity': 57.0, 'gp': 1.0}
# LaAdrian Waddle {'wind_speed': 33.0, 'tm_st_snp': 78.0, 'tm_off_snp': 306.0, 'tm_def_snp': 268.0, 'temperature': 287.0, 'humidity': 279.0, 'gp': 4.0}
# Zay Jones {'rec_yd': 195.0, 'off_snp': 583.0, 'gs': 8.0, 'gp': 14.0, 'tm_off_snp': 1013.0, 'wind_speed': 112.0, 'rec_ypt': 4.53, 'rec_pct': 833.3, 'gms_active': 14.0, 'rec_ypr': 7.8, 'pts_half_ppr': 32.3, 'rec_20_29': 2.0, 'st_snp': 14.0, 'idp_tkl': 2.0, 'rec_0_4': 6.0, 'tm_def_snp': 994.0, 'rush_ypa': 3.0, 'temperature': 904.0, 'rec': 25.0, 'rec_5_9': 9.0, 'rush_att': 1.0, 'idp_tkl_solo': 2.0, 'rush_lng': 3.0, 'rec_lng': 138.0, 'rec_10_19': 6.0, 'rec_tgt': 43.0, 'tm_st_snp': 334.0, 'rush_yd': 3.0, 'bonus_rec_wr': 25.0, 'pts_ppr': 44.8, 'humidity': 830.0, 'pts_std': 19.8, 'rec_fd': 9.0}
# Clayton Fejedelem {'wind_speed': 129.0, 'tm_st_snp': 357.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1036.0, 'temperature': 880.0, 'st_snp': 356.0, 'pts_std': 12.0, 'pts_ppr': 12.0, 'pts_half_ppr': 12.0, 'idp_tkl_solo': 11.0, 'idp_tkl_ast': 2.0, 'idp_tkl': 13.0, 'humidity': 1028.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 99.0}
# Danny Trevathan {'wind_speed': 130.0, 'tm_st_snp': 322.0, 'tm_off_snp': 1016.0, 'tm_def_snp': 1044.0, 'temperature': 706.0, 'st_snp': 12.0, 'sack_yd': 11.0, 'pts_std': 74.1, 'pts_ppr': 74.1, 'pts_half_ppr': 74.1, 'idp_tkl_solo': 50.0, 'idp_tkl_loss': 3.0, 'idp_tkl_ast': 20.0, 'idp_tkl': 70.0, 'idp_sack': 1.0, 'idp_qb_hit': 4.0, 'idp_pass_def': 1.0, 'idp_ff': 1.0, 'humidity': 611.0, 'gs': 9.0, 'gp': 9.0, 'gms_active': 9.0, 'def_snp': 572.0}
# Pernell McPhee {'wind_speed': 58.0, 'tm_st_snp': 162.0, 'tm_off_snp': 529.0, 'tm_def_snp': 440.0, 'temperature': 497.0, 'st_snp': 1.0, 'sack_yd': 14.5, 'pts_std': 39.45, 'pts_ppr': 39.45, 'pts_half_ppr': 39.4, 'idp_tkl_solo': 17.0, 'idp_tkl_loss': 7.0, 'idp_tkl_ast': 2.0, 'idp_tkl': 19.0, 'idp_sack': 3.0, 'idp_qb_hit': 6.0, 'idp_pass_def': 1.0, 'humidity': 538.0, 'gs': 7.0, 'gp': 7.0, 'gms_active': 7.0, 'def_snp': 267.0}
# Step Durham {'wind_speed': 36.0, 'tm_st_snp': 92.0, 'tm_off_snp': 282.0, 'tm_def_snp': 283.0, 'temperature': 294.0, 'humidity': 329.0, 'gp': 4.0}
# Chad Kelly {'wind_speed': 60.0, 'tm_st_snp': 199.0, 'tm_off_snp': 595.0, 'tm_def_snp': 576.0, 'temperature': 535.0, 'humidity': 582.0, 'gp': 9.0, 'gms_active': 1.0}
# Vernon Hargreaves {'wind_speed': 120.0, 'tm_st_snp': 364.0, 'tm_off_snp': 1057.0, 'tm_def_snp': 1075.0, 'temperature': 949.0, 'td': 1.0, 'st_snp': 90.0, 'pts_std': 74.5, 'pts_ppr': 74.5, 'pts_half_ppr': 74.5, 'idp_tkl_solo': 51.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 9.0, 'idp_tkl': 60.0, 'idp_pass_def': 6.0, 'idp_int_ret_yd': 15.0, 'idp_int': 1.0, 'idp_fum_ret_yd': 2.0, 'idp_fum_rec': 1.0, 'idp_def_td': 1.0, 'humidity': 912.0, 'gs': 11.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 845.0}
# Mike Pennel {'wind_speed': 86.0, 'tm_st_snp': 168.0, 'tm_off_snp': 548.0, 'tm_def_snp': 521.0, 'temperature': 340.0, 'st_snp': 8.0, 'sack_yd': 8.0, 'pts_std': 21.3, 'pts_ppr': 21.3, 'pts_half_ppr': 21.3, 'idp_tkl_solo': 9.0, 'idp_tkl_loss': 3.0, 'idp_tkl_ast': 9.0, 'idp_tkl': 18.0, 'idp_sack': 1.0, 'idp_qb_hit': 2.0, 'humidity': 407.0, 'gp': 7.0, 'gms_active': 7.0, 'def_snp': 142.0}
# Cameron Fleming {'wind_speed': 153.0, 'tm_st_snp': 297.0, 'tm_off_snp': 1055.0, 'tm_def_snp': 1039.0, 'temperature': 897.0, 'st_snp': 65.0, 'off_snp': 184.0, 'humidity': 948.0, 'gs': 2.0, 'gp': 13.0, 'gms_active': 13.0}
# Nico Falah {'wind_speed': 33.0, 'tm_st_snp': 96.0, 'tm_off_snp': 274.0, 'tm_def_snp': 261.0, 'temperature': 242.0, 'humidity': 180.0, 'gp': 4.0}
# Dakota Allen {'wind_speed': 32.0, 'tm_st_snp': 120.0, 'tm_off_snp': 314.0, 'tm_def_snp': 351.0, 'temperature': 220.0, 'st_snp': 41.0, 'pts_std': 1.0, 'pts_ppr': 1.0, 'pts_half_ppr': 1.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 284.0, 'gp': 4.0, 'gms_active': 4.0}
# Cole Mazza {'wind_speed': 112.0, 'tm_st_snp': 334.0, 'tm_off_snp': 994.0, 'tm_def_snp': 934.0, 'temperature': 938.0, 'st_snp': 110.0, 'off_snp': 9.0, 'idp_tkl_solo': 1.0, 'idp_tkl': 1.0, 'humidity': 910.0, 'gp': 15.0, 'gms_active': 15.0}
# Dion Lewis {'rec_yd': 164.0, 'off_snp': 368.0, 'gs': 1.0, 'gp': 15.0, 'tm_off_snp': 955.0, 'wind_speed': 93.0, 'rec_ypt': 5.13, 'bonus_rec_rb': 25.0, 'rec_pct': 1105.0, 'gms_active': 15.0, 'rec_ypr': 6.56, 'pts_half_ppr': 53.1, 'rec_20_29': 2.0, 'st_snp': 3.0, 'rec_0_4': 3.0, 'tm_def_snp': 1060.0, 'rush_ypa': 3.81, 'temperature': 880.0, 'rush_fd': 6.0, 'rec': 25.0, 'rec_5_9': 10.0, 'rush_att': 53.0, 'td': 1.0, 'rec_td': 1.0, 'rush_lng': 84.0, 'rec_lng': 143.0, 'rec_10_19': 4.0, 'rec_tgt': 32.0, 'tm_st_snp': 355.0, 'rush_yd': 202.0, 'pts_ppr': 65.6, 'fum_lost': 1.0, 'humidity': 865.0, 'fum': 1.0, 'pts_std': 40.6, 'rec_fd': 6.0}
# Jamon Brown {'wind_speed': 115.0, 'tm_st_snp': 353.0, 'tm_off_snp': 1101.0, 'tm_def_snp': 997.0, 'temperature': 978.0, 'st_snp': 40.0, 'off_snp': 602.0, 'humidity': 913.0, 'gs': 9.0, 'gp': 10.0, 'gms_active': 10.0}
# Jayron Kearse {'wind_speed': 118.0, 'tm_st_snp': 306.0, 'tm_off_snp': 987.0, 'tm_def_snp': 1026.0, 'temperature': 757.0, 'st_snp': 205.0, 'pts_std': 27.5, 'pts_ppr': 27.5, 'pts_half_ppr': 27.5, 'idp_tkl_solo': 15.0, 'idp_tkl_ast': 7.0, 'idp_tkl': 22.0, 'idp_pass_def': 6.0, 'idp_int': 1.0, 'humidity': 850.0, 'gs': 2.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 200.0}
# Howard Wilson {'wind_speed': 41.0, 'tm_st_snp': 96.0, 'tm_off_snp': 283.0, 'tm_def_snp': 264.0, 'temperature': 272.0, 'humidity': 221.0, 'gp': 4.0}
# Taiwan Jones {'wind_speed': 119.0, 'tm_st_snp': 317.0, 'tm_off_snp': 1030.0, 'tm_def_snp': 1028.0, 'temperature': 1024.0, 'st_snp': 146.0, 'idp_tkl_solo': 4.0, 'idp_tkl_ast': 4.0, 'idp_tkl': 8.0, 'humidity': 1011.0, 'gp': 10.0, 'gms_active': 10.0}
# Laurent Duvernay-Tardif {'wind_speed': 147.0, 'tm_st_snp': 325.0, 'tm_off_snp': 1012.0, 'tm_def_snp': 1043.0, 'temperature': 794.0, 'st_snp': 67.0, 'off_snp': 859.0, 'humidity': 867.0, 'gs': 13.0, 'gp': 13.0, 'gms_active': 13.0}
# Robert Spillane {'wind_speed': 35.0, 'tm_st_snp': 168.0, 'tm_off_snp': 470.0, 'tm_def_snp': 459.0, 'temperature': 284.0, 'st_snp': 144.0, 'pts_std': 7.5, 'pts_ppr': 7.5, 'pts_half_ppr': 7.5, 'idp_tkl_solo': 6.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 9.0, 'humidity': 281.0, 'gp': 7.0, 'gms_active': 7.0, 'def_snp': 1.0}
# Darqueze Dennard {'wind_speed': 114.0, 'tm_st_snp': 312.0, 'tm_off_snp': 925.0, 'tm_def_snp': 880.0, 'temperature': 754.0, 'st_snp': 45.0, 'pts_std': 40.0, 'pts_ppr': 40.0, 'pts_half_ppr': 40.0, 'idp_tkl_solo': 25.0, 'idp_tkl_loss': 2.0, 'idp_tkl_ast': 12.0, 'idp_tkl': 37.0, 'idp_qb_hit': 2.0, 'idp_pass_def': 5.0, 'humidity': 885.0, 'gs': 5.0, 'gp': 8.0, 'gms_active': 8.0, 'def_snp': 461.0}
# Ventell Bryant {'wind_speed': 119.0, 'tm_st_snp': 229.0, 'tm_off_snp': 787.0, 'tm_def_snp': 765.0, 'temperature': 561.0, 'td': 1.0, 'st_snp': 184.0, 'rec_ypt': 15.0, 'rec_ypr': 15.0, 'rec_yd': 15.0, 'rec_tgt': 1.0, 'rec_td': 1.0, 'rec_pct': 100.0, 'rec_lng': 15.0, 'rec_10_19': 1.0, 'rec': 1.0, 'pts_std': 7.5, 'pts_ppr': 8.5, 'pts_half_ppr': 8.0, 'off_snp': 14.0, 'idp_tkl_solo': 6.0, 'idp_tkl': 6.0, 'humidity': 660.0, 'gp': 11.0, 'gms_active': 11.0, 'bonus_rec_wr': 1.0}
# Ito Smith {'kr_yd': 59.0, 'rec_yd': 87.0, 'off_snp': 153.0, 'gp': 7.0, 'tm_off_snp': 563.0, 'wind_speed': 55.0, 'rec_ypt': 6.21, 'bonus_rec_rb': 11.0, 'rec_pct': 316.7, 'gms_active': 7.0, 'rec_ypr': 7.91, 'pts_half_ppr': 30.8, 'st_snp': 7.0, 'rec_0_4': 1.0, 'kr_ypa': 29.5, 'tm_def_snp': 548.0, 'rush_ypa': 4.82, 'temperature': 624.0, 'rush_fd': 9.0, 'kr_lng': 33.0, 'rec': 11.0, 'rec_5_9': 6.0, 'rush_att': 22.0, 'td': 1.0, 'rush_lng': 75.0, 'rec_lng': 37.0, 'rec_10_19': 4.0, 'rec_tgt': 14.0, 'tm_st_snp': 192.0, 'rush_yd': 106.0, 'rush_td': 1.0, 'pts_ppr': 36.3, 'humidity': 580.0, 'pts_std': 25.3, 'rec_fd': 2.0, 'kr': 2.0}
# Matthew Adams {'wind_speed': 106.0, 'tm_st_snp': 333.0, 'tm_off_snp': 1036.0, 'tm_def_snp': 968.0, 'temperature': 922.0, 'st_snp': 284.0, 'pts_std': 10.0, 'pts_ppr': 10.0, 'pts_half_ppr': 10.0, 'idp_tkl_solo': 8.0, 'idp_tkl_loss': 1.0, 'idp_tkl_ast': 2.0, 'idp_tkl': 10.0, 'humidity': 939.0, 'gs': 4.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 104.0}
# Austin Carr {'wind_speed': 93.0, 'tm_st_snp': 346.0, 'tm_off_snp': 1014.0, 'tm_def_snp': 1012.0, 'temperature': 980.0, 'st_snp': 4.0, 'rec_ypt': 2.25, 'rec_ypr': 9.0, 'rec_yd': 9.0, 'rec_tgt': 4.0, 'rec_pct': 50.0, 'rec_lng': 9.0, 'rec_fd': 1.0, 'rec_5_9': 1.0, 'rec': 1.0, 'pts_std': 0.9, 'pts_ppr': 1.9, 'pts_half_ppr': 1.4, 'off_snp': 192.0, 'humidity': 988.0, 'gs': 3.0, 'gp': 6.0, 'gms_active': 6.0, 'bonus_rec_wr': 1.0}
# Maurice Hurst {'wind_speed': 110.0, 'tm_st_snp': 349.0, 'tm_off_snp': 964.0, 'tm_def_snp': 999.0, 'temperature': 803.0, 'st_snp': 79.0, 'sack_yd': 39.5, 'pts_std': 45.95, 'pts_ppr': 45.95, 'pts_half_ppr': 45.9, 'idp_tkl_solo': 9.0, 'idp_tkl_loss': 3.5, 'idp_tkl_ast': 7.0, 'idp_tkl': 16.0, 'idp_sack': 3.5, 'idp_qb_hit': 7.0, 'idp_pass_def': 3.0, 'idp_int_ret_yd': 55.0, 'idp_int': 1.0, 'idp_fum_rec': 2.0, 'humidity': 824.0, 'gs': 3.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 497.0}
# Kevin King {'wind_speed': 119.0, 'tm_st_snp': 313.0, 'tm_off_snp': 1020.0, 'tm_def_snp': 987.0, 'temperature': 724.0, 'st_snp': 16.0, 'sack_yd': 2.0, 'pts_std': 97.2, 'pts_ppr': 97.2, 'pts_half_ppr': 97.2, 'idp_tkl_solo': 54.0, 'idp_tkl_loss': 3.5, 'idp_tkl_ast': 9.0, 'idp_tkl': 63.0, 'idp_sack': 1.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 14.0, 'idp_int_ret_yd': 54.0, 'idp_int': 5.0, 'idp_ff': 1.0, 'humidity': 698.0, 'gs': 13.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 754.0}
# Deion Calhoun {'wind_speed': 178.0, 'tm_st_snp': 370.0, 'tm_off_snp': 1017.0, 'tm_def_snp': 1060.0, 'temperature': 1016.0, 'st_snp': 30.0, 'off_snp': 408.0, 'humidity': 894.0, 'gs': 6.0, 'gp': 9.0, 'gms_active': 11.0}
# Bashaud Breeland {'wind_speed': 147.0, 'tm_st_snp': 325.0, 'tm_off_snp': 1012.0, 'tm_def_snp': 1043.0, 'temperature': 794.0, 'td': 1.0, 'st_snp': 2.0, 'pts_std': 67.0, 'pts_ppr': 67.0, 'pts_half_ppr': 67.0, 'idp_tkl_solo': 35.0, 'idp_tkl_ast': 10.0, 'idp_tkl': 45.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 8.0, 'idp_int_ret_yd': 4.0, 'idp_int': 2.0, 'idp_fum_ret_yd': 114.0, 'idp_fum_rec': 2.0, 'idp_def_td': 1.0, 'humidity': 867.0, 'gs': 14.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 888.0}
# Artie Burns {'wind_speed': 72.0, 'tm_st_snp': 314.0, 'tm_off_snp': 968.0, 'tm_def_snp': 1029.0, 'temperature': 776.0, 'st_snp': 121.0, 'pts_std': 7.0, 'pts_ppr': 7.0, 'pts_half_ppr': 7.0, 'idp_tkl_solo': 5.0, 'idp_tkl_loss': 0.5, 'idp_tkl_ast': 3.0, 'idp_tkl': 8.0, 'humidity': 762.0, 'gs': 1.0, 'gp': 10.0, 'gms_active': 10.0, 'def_snp': 66.0}
# Mike McGlinchey {'wind_speed': 67.0, 'tm_st_snp': 329.0, 'tm_off_snp': 1036.0, 'tm_def_snp': 946.0, 'temperature': 929.0, 'st_snp': 66.0, 'off_snp': 745.0, 'humidity': 886.0, 'gs': 11.0, 'gp': 11.0, 'gms_active': 11.0}
# Geno Atkins {'wind_speed': 129.0, 'tm_st_snp': 357.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1036.0, 'temperature': 880.0, 'st_snp': 4.0, 'sack_yd': 28.0, 'pts_std': 56.3, 'pts_ppr': 56.3, 'pts_half_ppr': 56.3, 'idp_tkl_solo': 16.0, 'idp_tkl_loss': 6.5, 'idp_tkl_ast': 26.0, 'idp_tkl': 42.0, 'idp_sack': 4.5, 'idp_qb_hit': 9.0, 'humidity': 1028.0, 'gs': 13.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 793.0}
# Ali Marpet {'wind_speed': 122.0, 'tm_st_snp': 377.0, 'tm_off_snp': 1108.0, 'tm_def_snp': 1077.0, 'temperature': 952.0, 'st_snp': 83.0, 'off_snp': 1108.0, 'idp_tkl_solo': 2.0, 'idp_tkl': 2.0, 'humidity': 945.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0}
# Jacob Tuioti-Mariner {'wind_speed': 60.0, 'tm_st_snp': 161.0, 'tm_off_snp': 538.0, 'tm_def_snp': 449.0, 'temperature': 354.0, 'st_snp': 46.0, 'pts_std': 9.5, 'pts_ppr': 9.5, 'pts_half_ppr': 9.5, 'idp_tkl_solo': 5.0, 'idp_tkl_loss': 0.5, 'idp_tkl_ast': 6.0, 'idp_tkl': 11.0, 'idp_qb_hit': 1.0, 'humidity': 333.0, 'gp': 7.0, 'gms_active': 7.0, 'def_snp': 158.0}
# Jamal Carter {'wind_speed': 85.0, 'tm_st_snp': 272.0, 'tm_off_snp': 816.0, 'tm_def_snp': 728.0, 'temperature': 668.0, 'st_snp': 170.0, 'pts_std': 8.0, 'pts_ppr': 8.0, 'pts_half_ppr': 8.0, 'idp_tkl_solo': 5.0, 'idp_tkl_ast': 4.0, 'idp_tkl': 9.0, 'idp_pass_def': 1.0, 'humidity': 594.0, 'gp': 10.0, 'gms_active': 10.0, 'def_snp': 97.0}
# Matt Prater {'xpmiss': 1.0, 'xpm': 33.0, 'xpa': 34.0, 'wind_speed': 127.0, 'tm_st_snp': 372.0, 'tm_off_snp': 1043.0, 'tm_def_snp': 1065.0, 'temperature': 777.0, 'st_snp': 71.0, 'pts_std': 117.0, 'pts_ppr': 117.0, 'pts_half_ppr': 117.0, 'off_snp': 14.0, 'humidity': 709.0, 'gp': 15.0, 'gms_active': 15.0, 'fgmiss_50p': 1.0, 'fgmiss_40_49': 3.0, 'fgmiss_30_39': 1.0, 'fgmiss': 5.0, 'fgm_yds_over_30': 223.0, 'fgm_yds': 876.0, 'fgm_pct': 1091.7, 'fgm_lng': 514.0, 'fgm_50p': 6.0, 'fgm_40_49': 5.0, 'fgm_30_39': 2.0, 'fgm_20_29': 11.0, 'fgm': 24.0, 'fga': 29.0, 'fg_blkd': 1.0}
# Justin Reid {'wind_speed': 119.0, 'tm_st_snp': 317.0, 'tm_off_snp': 1030.0, 'tm_def_snp': 1028.0, 'temperature': 1024.0, 'st_snp': 25.0, 'pts_std': 82.0, 'pts_ppr': 82.0, 'pts_half_ppr': 82.0, 'idp_tkl_solo': 55.0, 'idp_tkl_loss': 1.5, 'idp_tkl_ast': 21.0, 'idp_tkl': 76.0, 'idp_qb_hit': 1.0, 'idp_pass_def': 5.0, 'idp_int_ret_yd': 55.0, 'idp_int': 2.0, 'idp_fum_rec': 1.0, 'humidity': 1011.0, 'gs': 14.0, 'gp': 14.0, 'gms_active': 14.0, 'def_snp': 899.0}
# Cole Madison {'wind_speed': 119.0, 'tm_st_snp': 313.0, 'tm_off_snp': 1020.0, 'tm_def_snp': 987.0, 'temperature': 724.0, 'humidity': 698.0, 'gp': 15.0}
# Darian Stewart {'wind_speed': 122.0, 'tm_st_snp': 377.0, 'tm_off_snp': 1108.0, 'tm_def_snp': 1077.0, 'temperature': 952.0, 'st_snp': 106.0, 'pts_std': 6.5, 'pts_ppr': 6.5, 'pts_half_ppr': 6.5, 'idp_tkl_solo': 4.0, 'idp_tkl_ast': 3.0, 'idp_tkl': 7.0, 'idp_pass_def': 1.0, 'humidity': 945.0, 'gs': 1.0, 'gp': 12.0, 'gms_active': 14.0, 'def_snp': 135.0}
# Anthony Walker {'wind_speed': 106.0, 'tm_st_snp': 333.0, 'tm_off_snp': 1036.0, 'tm_def_snp': 968.0, 'temperature': 922.0, 'st_snp': 131.0, 'sack_yd': 3.0, 'pts_std': 114.8, 'pts_ppr': 114.8, 'pts_half_ppr': 114.8, 'idp_tkl_solo': 72.0, 'idp_tkl_loss': 8.0, 'idp_tkl_ast': 35.0, 'idp_tkl': 107.0, 'idp_sack': 2.5, 'idp_qb_hit': 4.0, 'idp_pass_def': 2.0, 'idp_int': 1.0, 'idp_ff': 1.0, 'humidity': 939.0, 'gs': 15.0, 'gp': 15.0, 'gms_active': 15.0, 'def_snp': 755.0}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-82ded3930c62> in <module>
#       4 for pid in all_stats.keys():
#       5     if is_pid(pid):
# ----> 6         player = Player(pid)
#       7         player.set_stats(all_stats[pid])
#       8         if len(player.stats) > 0:
#
# <ipython-input-68-474085a5465b> in __init__(self, pid)
#       1 class Player:
#       2     def __init__(self, pid):
# ----> 3         self.data = all_players[pid]
#       4         self.pid = pid
#       5         self.name = self.data['full_name']
#
# KeyError: '6704'

# %%
## Choose a position and a value to sort by
## output is the ranks of players at position in said category
## FA if true: Only considers unowned players, make sure appropriate cell is run above
#### FA if false: Considers all players, make sure appropriate cell is run above

pos = 'WR'
sort_by_val = 'tm_off_snp'
fa = True 
pos_players = []
if fa:
    for player in free_agents:
        if player.fantasy_positions == [pos] and player.team != None:
            if (len(all_stats[player.pid]) > 0):
                player.set_stats(all_stats[player.pid])
                pos_players.append(player)
else: 
    for player in all_players.keys():
        if is_pid(player):
            temp = Player(player)
            if temp.fantasy_positions == [pos] and temp.team != None:
                if (len(all_stats[player]) > 0):
                    temp.set_stats(all_stats[player])
                    pos_players.append(temp)
names = []       
data = []
for player in pos_players:
    names.append(player.name)
    data.append(player.stats)
df = pd.DataFrame(data=data, index=names)
df = df.sort_values(by=[sort_by_val], ascending=False)
df = df.dropna(axis='columns', how='all')
ranks = df.index
ind = 1 
for label in ranks:
    print('Rank %d: %s' % (ind, label))
    ind += 1

# %%
df_all = pd.DataFrame (data=all_players.values(), index=all_players.keys())
df_all = pd.DataFrame(data=all_players.values(), index=df_all['full_name'])
dropsies = ['last_name', 'search_last_name', 'rotoworld_id', 'injury_notes', 'yahoo_id', 'search_rank', 
            'full_name', 'hashtag', 'search_first_name', 'espn_id', 'sportradar_id', 
           'news_updated', 'search_full_name', 'sport', 'birth_country', 'gsis_id', 'fantasy_data_id', 'stats_id',
           'rotowire_id', 'first_name']
df_mod = df_all.drop(labels=dropsies, axis='columns')

# %%
## Calculate the record of playing everyone, everyweek.
## Loop through week
#### Loop through matchups for the week, get your point total
###### Loop through every other team, check their point total, see if you won or lost
###### Keep track of total wins/losses for every team


tid2rec = {}
for i in range(1, len(users) + 1):
    tid2rec[i] = (0,0)
for i in range(1,14):
    matchups = league.get_matchups(i)
    for matchup in matchups:
        tid = matchup['roster_id']
        points = matchup['points']
        other_matchups = league.get_matchups(i)
        wins = 0
        losses = 0
        for other_matchup in other_matchups:
            other_points = other_matchup['points']
            if points != other_points:
                if points > other_points:
                    wins += 1
                else: 
                    losses += 1
        curr_rec = tid2rec[tid]
        updated_wins = curr_rec[0] + wins
        updated_l = curr_rec[1] + losses
        tid2rec[tid] = (updated_wins, updated_l)

res = []
for tid in tid2rec.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            record = tid2rec[tid]
            res.append((owner_name, record))
            
res.sort(key = lambda x: x[1][0], reverse=True)
for result in res:
    print('%s: %d-%d' % (result[0], result[1][0], result[1][1]))
# Out:
# Horny1: 86-31
# Jonny2Time: 70-47
# JoSchmo: 69-48
# FlashYourTDs: 69-48
# MrJanuary: 64-53
# MrLonghorn: 56-61
# BeerdedJustice: 52-65
# Steeler1979: 43-74
# bmass: 42-75
# Micahangelo: 34-83

# %%
## Calculate the Z-score for your opponent each week and yourself each week 
## Loop through week
#### Loop through matchups for the week get the z-score of each point total
#### Loop through each matchup and if its your team, keep track of your z-scores
###### Loop through every other team, if your opponent, keep tracj of their z-score
###### Keep track of both z-scores throughout 13 week regular season


from scipy.stats import zscore

myscores = {}
tid2zscores = {}
for i in range(1, len(users) + 1):
    tid2zscores[i] = []
    myscores[i] = []

for week in range(1, 14):
    matchups = league.get_matchups(week)
    scores = []
    for matchup in matchups:
        scores.append(matchup['points'])
    z_scores = zscore(scores)
    for matchup in matchups:
        tid = matchup['roster_id']
        matchup_id = matchup['matchup_id']
        myscores[tid].append(z_scores[tid - 1])
        other_matchups = league.get_matchups(week)
        for other_matchup in other_matchups:
            other_mid = other_matchup['matchup_id']
            other_tid = other_matchup['roster_id']
            if matchup_id == other_mid and tid != other_tid:
                z_score = z_scores[other_tid - 1]
                tid2zscores[tid].append(z_score)

# %%
res = []
for tid in tid2zscores.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            z_score_mean = np.mean(tid2zscores[tid])
            my_zscore = np.mean(myscores[tid])
            res.append((owner_name, z_score_mean, my_zscore))
            
res.sort(key = lambda x: x[1], reverse=True)
for result in res:
    print('%s: Z-Score against: %.4f' % (result[0], result[1]))
# Out:
# Steeler1979: Z-Score against: 0.2978
# Micahangelo: Z-Score against: 0.2807
# MrLonghorn: Z-Score against: 0.1382
# bmass: Z-Score against: 0.0670
# JoSchmo: Z-Score against: 0.0125
# BeerdedJustice: Z-Score against: 0.0068
# FlashYourTDs: Z-Score against: -0.1170
# Horny1: Z-Score against: -0.1301
# Jonny2Time: Z-Score against: -0.2276
# MrJanuary: Z-Score against: -0.3283

# %%
res = []
for tid in tid2zscores.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            z_score_mean = np.mean(tid2zscores[tid])
            my_zscore = np.mean(myscores[tid])
            res.append((owner_name, z_score_mean, my_zscore))
            
res.sort(key = lambda x: x[2], reverse=True)
for result in res:
    print('%s: Z-Score points for: %.4f' % (result[0], result[2]))
# Out:
# Horny1: Z-Score points for: 0.8077
# Jonny2Time: Z-Score points for: 0.2966
# MrJanuary: Z-Score points for: 0.2301
# FlashYourTDs: Z-Score points for: 0.1596
# JoSchmo: Z-Score points for: 0.1016
# MrLonghorn: Z-Score points for: -0.0032
# BeerdedJustice: Z-Score points for: -0.2432
# bmass: Z-Score points for: -0.3749
# Steeler1979: Z-Score points for: -0.4258
# Micahangelo: Z-Score points for: -0.5487

# %%
matchups = league.get_matchups(1)
print(matchups)
# Out:
# [{'starters': ['4046', '4866', '3198', '2378', '4037', '3225', '1149', '4217', '5010', '1817', '4082', '289', '49', '594', '3172', '2015', '2429', '3254', '187', '3262', '5017', '4081', '3747'], 'roster_id': 1, 'points': 490.07000732421875, 'players': ['695', '5864', '5967', '49', '6039', '2135', '4046', '5911', '6007', '289', '1817', '5962', '5889', '829', '5885', '5947', '5872', '4037', '2821', '4082', '5917', '3747', '5955', '5884', '1149', '3262', '6045', '4150', '5840', '3198', '4217', '3254', '3225', '4951', '594', '187', '3172', '6056', '2429', '5379', '4866', '4993', '4081', '2378', '6107', '4078', '6136', '2015', '5017', '5010', '6002'], 'matchup_id': 4, 'custom_points': None}, {'starters': ['24', '4988', '5068', '956', '3321', '344', '4039', '1587', '284', '538', '1848', '3161', '127', '1513', '2592', '550', '4063', '1255', '4191', '88', '531', '1686', '1415'], 'roster_id': 2, 'points': 384.8599853515625, 'players': ['2355', '1848', '928', '24', '138', '1686', '5068', '1346', '2399', '956', '1587', '1255', '2452', '531', '4063', '6178', '5038', '2592', '1415', '6156', '4149', '4988', '4972', '5937', '6126', '344', '1053', '3309', '5995', '5843', '88', '147', '1513', '1555', '4039', '515', '3238', '284', '2320', '1144', '538', '550', '3161', '1971', '127', '1793', '3321', '4191'], 'matchup_id': 4, 'custom_points': None}, {'starters': ['4017', '4034', '4199', '4152', '947', '3157', '1825', '4033', '616', '2319', '5844', '167', '1266', '5015', '4032', '856', '2350', '3166', '1875', '3194', '643', '5036', '1576'], 'roster_id': 3, 'points': 470.05999755859375, 'players': ['6139', '2545', '5015', '1875', '5117', '4199', '2350', '643', '6214', '1837', '947', '2257', '1854', '4174', '4017', '4964', '3194', '5036', '4203', '2319', '536', '4152', '1825', '110', '1386', '5846', '5056', '4034', '856', '616', '4965', '4994', '1266', '1556', '4033', '3157', '5071', '2346', '3166', '1576', '5987', '5959', '167', '6148', '5013', '869', '5844', '4032', '5852', '5226'], 'matchup_id': 3, 'custom_points': None}, {'starters': ['3976', '4029', '6151', '4949', '2078', '4036', '4950', '4055', '4066', '4157', '5045', '5849', '5230', '605', '5020', '5483', '4220', '3291', '3222', '1395', '2230', '714', '2645'], 'roster_id': 4, 'points': 343.6400146484375, 'players': ['4036', '830', '5045', '5880', '2341', '5020', '3680', '5375', '2645', '1808', '2230', '2078', '6128', '4157', '5230', '583', '1395', '2108', '4055', '2064', '5302', '3868', '5915', '5849', '3222', '4066', '3976', '1043', '5859', '4144', '1029', '1192', '6291', '6151', '4949', '5044', '5483', '5886', '3191', '6014', '3291', '4220', '714', '1367', '2414', '4029', '4065', '605', '2004', '4950', '846'], 'matchup_id': 5, 'custom_points': None}, {'starters': ['4881', '4018', '5892', '4455', '4040', '2374', '1244', '3202', '5857', '4131', '4068', '4943', '3827', '2368', '495', '2393', '4070', '2062', '3167', '4056', '4216', '4974', '1905'], 'roster_id': 5, 'points': 336.489990234375, 'players': ['4216', '5536', '4455', '2084', '6153', '2343', '4158', '3167', '2374', '3257', '4056', '4974', '19', '3202', '5857', '2368', '3827', '2393', '4881', '2460', '6179', '5409', '184', '4067', '5847', '4018', '2062', '5927', '5863', '296', '5842', '5046', '4070', '5860', '4992', '6133', '5973', '495', '232', '5892', '1244', '4943', '4068', '4040', '2689', '1905', '4131', '5131'], 'matchup_id': 1, 'custom_points': None}, {'starters': ['4892', '4035', '4273', '4962', '2309', '2449', '4983', '2505', '943', '3423', '3200', '3294', '4227', '1947', '2036', '3973', '6119', '5041', '4968', '4133', '544', '3181', '2348'], 'roster_id': 6, 'points': 423.8500061035156, 'players': ['5870', '6068', '1160', '5970', '2348', '4962', '5965', '444', '4968', '4133', '5906', '2028', '678', '2309', '5009', '6124', '4892', '3451', '5139', '5041', '2449', '3423', '1947', '943', '5830', '4035', '5101', '544', '3973', '2505', '6119', '1388', '6118', '3230', '2036', '1940', '5086', '5816', '4983', '2588', '3294', '3200', '31 ...

# %%
point_vals = {'pass_td' : 6, 'pass_yd' : .04, 'pass_td_40p' : 2, 'pass_cmp_40p' : 1, 'pass_2pt' : 2,
              'rush_td' : 8, 'rush_yd' : 0.1, 'rush_td_40p' : 2,'rush_40p' : 1, 'rush_2pt' : 2,
              'rec' : 1, 'rec_td' : 6, 'rec_yd' : .1, 'rec_40p' : 1, 'rec_2pt' : 2, 
              'bonus_rec_wr' : 0.5, 'bonus_rec_rb' : 0.5, 'bonus_rec_te' : 2,
              'pr_yd' : .07, 'pr_td' : 6, 'kr_yd' : .07, 'kr_td' : 6,
              'fum' : -1, 'fum_lost' : -2, 'pass_int' : -1, 'idp_tkl_loss': 3.5, 'idp_tkl_ast': 1, 'idp_tkl': 2, 
              'idp_sack': 4, 'idp_qb_hit': 2, 'idp_pass_def': 2.5, 'idp_ff': 3, 'idp_def_td' : 6,
              'idp_int' : 5, 'idp_fum_rec' : 4, 'idp_safe' : 10, 'idp_blk_kick': 6}
              
t_point_vals = {'pass_td' : 4, 'pass_yd' : .04, 'pass_td_40p' : 0, 'pass_cmp_40p' : 0, 'pass_2pt' : 2,
              'rush_td' : 6, 'rush_yd' : 0.1, 'rush_td_40p' : 0,'rush_40p' : 0, 'rush_2pt' : 2,
              'rec' : 0.5, 'rec_td' : 6, 'rec_yd' : .1, 'rec_40p' : 0, 'rec_2pt' : 2, 
              'bonus_rec_wr' : 0, 'bonus_rec_rb' : 0, 'bonus_rec_te' : 0,
              'pr_yd' : 0, 'pr_td' : 0, 'kr_yd' : 0, 'kr_td' : 0,
              'fum' : -1, 'fum_lost' : -2, 'pass_int' : -1, 'idp_tkl_loss': 0, 'idp_tkl_ast': 0, 'idp_tkl': 0, 
              'idp_sack': 0, 'idp_qb_hit': 0, 'idp_pass_def': 0, 'idp_ff': 0, 'idp_def_td' : 0,
              'idp_int' : 0, 'idp_fum_rec' : 0, 'idp_safe' : 0, 'idp_blk_kick': 0}

### if position = "K" use points ppr


def calc_points(stats):
    total = 0
    for stat in stats:
        if stat in point_vals.keys():
            total += stats[stat] * point_vals[stat]
    return total

# %%
## Calculate points that are from offense vs defense in a given week
## COULD adapt to do a position based percentage

offensive_positions = ['QB', 'RB', 'WR', 'TE', 'K']
tid2percent_o = {}
tid2percent_d = {}
stats = Stats()
for i in range(1, len(users) + 1):
    tid2percent_o[i] = []
    tid2percent_d[i] = []
    
for week in range(1, 14):
    matchups = league.get_matchups(week)
    scores = []
    week_stats = stats.get_week_stats('regular', 2019, week)
    for matchup in matchups:
        tid = matchup['roster_id']
        matchup_id = matchup['matchup_id']
        starters = matchup['starters']
        total_points = calc_weekly_points(starters, week_stats)
        offensive_points = 0
        defensive_points = 0
        for starter in starters:
            player = Player(starter)
            if starter not in week_stats:
                continue
            player_stats = week_stats[starter]
            position = player.position
            point = 0
            if position in offensive_positions:
                if position == 'K':
                    if 'pts_std' in player_stats:
                        point = player_stats['pts_std']
                else:
                    point = calc_points(player_stats)
                offensive_points += point
            else:
                point = calc_points(player_stats)
                defensive_points += point
        tid2percent_o[tid].append(offensive_points / total_points)
        tid2percent_d[tid].append(defensive_points / total_points)
        

        
res = []
for tid in tid2rec.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            percent_o = tid2percent_o[tid]
            percent_d = tid2percent_d[tid]
            res.append((owner_name, np.mean(percent_o), np.mean(percent_d)))
            
res.sort(key = lambda x: x[1], reverse=True)
print('Average point percentage from Offense\n')
for result in res:
    print('%s: %.2f' % (result[0], result[1]))
            
print('\nAverage point percentage from Defense\n')
res.sort(key = lambda x: x[2], reverse=True)
for result in res:
    print('%s: %.2f' % (result[0], result[2]))
# Out:
# Average point percentage from Offense
#
# Oz75: 1.00
# chett: 1.00
# PolkFiction: 1.00
# ravensarmy123: 1.00
# Philoh: 1.00
# Zfagan103: 1.00
# WildcardSports: 1.00
# jsemmens: 1.00
# JusMan: 1.00
# BXBenny: 1.00
# kickinwing: 1.00
# MrLonghorn: 1.00
#
# Average point percentage from Defense
#
# Oz75: 0.00
# chett: 0.00
# PolkFiction: 0.00
# ravensarmy123: 0.00
# Philoh: 0.00
# Zfagan103: 0.00
# WildcardSports: 0.00
# jsemmens: 0.00
# JusMan: 0.00
# BXBenny: 0.00
# kickinwing: 0.00
# MrLonghorn: 0.00

# %%
## Function to calculate points scored given the starters and the stats for said starters

def calc_weekly_points(starters, weekly_stats):
    total = 0
    for starter in starters:
        player = Player(starter)
        if starter not in week_stats:
            continue
        player_stats = week_stats[starter]
        position = player.position
        point = 0
        if position == 'K':
            if 'pts_std' in player_stats:
                point = player_stats['pts_std']
        else:
            point = calc_points(player_stats)
        total += point
    return total

# %%
## Proof that Sleeper is not all that:
## Uses a manual calculation of weekly points to calculate record
## Prints output of matchups where something should be changed


tid2rec = {}
stats = Stats()
for i in range(1, len(users) + 1):
    tid2rec[i] = (0,0)
for i in range(1,14):
    matchups = league.get_matchups(i)
    week_stats = stats.get_week_stats('regular', 2019, i)
    for matchup in matchups:
        tid = matchup['roster_id']
        starters = matchup['starters']
        points = calc_weekly_points(starters, week_stats)
        other_matchups = league.get_matchups(i)
        wins = 0
        losses = 0
        for other_matchup in other_matchups:
            other_tid = other_matchup['roster_id']
            if matchup['matchup_id'] == other_matchup['matchup_id'] and tid != other_tid:
                other_starters = other_matchup['starters']
                other_points = 0
                other_points = calc_weekly_points(other_starters, week_stats)
                if points > other_points:
                    wins += 1
                    if matchup['points'] < other_matchup['points']:
                        print("Check week %d, matchup with %s" % (i, tid))
                else: 
                    losses += 1
        curr_rec = tid2rec[tid]
        updated_wins = curr_rec[0] + wins
        updated_l = curr_rec[1] + losses
        tid2rec[tid] = (updated_wins, updated_l)

res = []
for tid in tid2rec.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            record = tid2rec[tid]
            res.append((owner_name, record))
            
res.sort(key = lambda x: x[1][0], reverse=True)
for result in res:
    print('%s: %d-%d' % (result[0], result[1][0], result[1][1]))
# Out:
# PolkFiction: 10-3
# WildcardSports: 9-4
# JusMan: 8-5
# ravensarmy123: 7-6
# jsemmens: 7-6
# BXBenny: 7-6
# MrLonghorn: 7-6
# Philoh: 6-7
# chett: 5-8
# Oz75: 4-9
# Zfagan103: 4-9
# kickinwing: 4-9

# %%
def get_points_by_pos(pos):
    tid2pospercent = {}
    stats = Stats()
    for i in range(1, len(users) + 1):
        tid2pospercent[i] = []

    for week in range(1, 14):
        matchups = league.get_matchups(week)
        scores = []
        week_stats = stats.get_week_stats('regular', 2019, week)
        for matchup in matchups:
            tid = matchup['roster_id']
            matchup_id = matchup['matchup_id']
            starters = matchup['starters']
            total_points = calc_weekly_points(starters, week_stats)
            pos_points = 0
            for starter in starters:
                player = Player(starter)
                if starter not in week_stats:
                    continue
                player_stats = week_stats[starter]
                positions = player.fantasy_positions
                if pos in list(positions):
                    if pos == 'K':
                        if 'pts_std' in player_stats:
                            pos_points += player_stats['pts_std']
                    else:
                        pos_points += calc_points(player_stats)
            tid2pospercent[tid].append(pos_points / total_points)  
    return tid2pospercent
        
res = []
pos = 'QB'
tid2pospercent = get_points_by_pos(pos)
for tid in tid2pospercent.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            posp = tid2pospercent[tid]
            res.append((owner_name, np.mean(posp)))
            
res.sort(key = lambda x: x[1], reverse=True)
print('Average point percentage from %s\n' % (pos))
for result in res:
    print('%s: %.2f' % (result[0], result[1]))
# Out:
# Average point percentage from QB
#
# WildcardSports: 0.28
# Oz75: 0.27
# kickinwing: 0.27
# jsemmens: 0.26
# Philoh: 0.26
# Zfagan103: 0.25
# PolkFiction: 0.21
# MrLonghorn: 0.21
# ravensarmy123: 0.20
# BXBenny: 0.18
# JusMan: 0.18
# chett: 0.16

# %%
all_fp = ['QB', 'RB', 'WR', 'TE', 'K', 'DL', 'LB', 'DB']
res_dic = {}
for i in range(1, len(users) + 1):
    res_dic[i] = {}
    for fp in all_fp:
        res_dic[i][fp] = 0

fp_percent = []
for fp in all_fp:
    print (fp)
    percentages = get_points_by_pos(fp)
    for tid in percentages.keys():
        res_dic[tid][fp] = np.mean(percentages[tid])
# Out:
# QB
# RB
# WR
# TE

# %%
## Breaks down average point totals by position

res = []
for tid in res_dic.keys():
    for team in teams:
        if team.tid + 1 == tid:
            owner_name = team.owner_name
            pos_dic = res_dic[tid]
            norm_list = []
            total = np.sum(list(pos_dic.values()))
            for value in pos_dic.values():
                norm_list.append(value / total)
            ind = 0
            norm_dic = {}
            for posit in pos_dic.keys():
                norm_dic[posit] = norm_list[ind] * 100
                ind += 1
            res.append((owner_name, norm_dic))
            
res.sort(key = lambda x: x[1]['QB'], reverse=True)
for result in res:
    print('%s: %s\n' % (result[0], result[1]))
# Out:
# jsemmens: {'QB': 24.04824263085436, 'RB': 24.594740782644003, 'WR': 41.4487848389871, 'TE': 9.908231747514524}
#
# Philoh: {'QB': 23.44038872230628, 'RB': 22.861338031813542, 'WR': 48.29473939439818, 'TE': 5.403533851481999}
#
# BXBenny: {'QB': 22.213877456750826, 'RB': 24.83924311886467, 'WR': 40.62352681647336, 'TE': 12.323352607911142}
#
# Zfagan103: {'QB': 22.148877842319788, 'RB': 26.65076429740975, 'WR': 33.43101780424493, 'TE': 17.769340056025527}
#
# Oz75: {'QB': 22.04602311610987, 'RB': 36.55587779081525, 'WR': 23.71580720325433, 'TE': 17.682291889820544}
#
# JusMan: {'QB': 19.552152001303682, 'RB': 40.03029039025644, 'WR': 31.470601979572493, 'TE': 8.946955628867384}
#
# ravensarmy123: {'QB': 18.93522541576663, 'RB': 23.659288091700365, 'WR': 49.08882325179508, 'TE': 8.316663240737947}
#
# WildcardSports: {'QB': 18.846914764665915, 'RB': 38.0172777770869, 'WR': 35.645994381089395, 'TE': 7.489813077157806}
#
# kickinwing: {'QB': 17.294823332373447, 'RB': 48.29220645118636, 'WR': 28.406724971458715, 'TE': 6.006245244981478}
#
# PolkFiction: {'QB': 17.005551874163423, 'RB': 40.15301580906399, 'WR': 37.06396829098979, 'TE': 5.777464025782794}
#
# MrLonghorn: {'QB': 13.897747029204691, 'RB': 36.50586086596834, 'WR': 37.440087027054574, 'TE': 12.156305077772396}
#
# chett: {'QB': 12.816528803920468, 'RB': 35.268078003342836, 'WR': 45.888757746347736, 'TE': 6.0266354463889655}
